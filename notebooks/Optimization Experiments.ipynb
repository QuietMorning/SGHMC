# %%
import numpy as np
from functools import partial
import matplotlib.pyplot as plt
import seaborn as sns
import time
import numba
from numba import njit

# %% [markdown]
# ### Optimization for sghmc algorithm with gradient function

# %%
## potential energy function
U = lambda x:  -2*x**2 + x**4
gradU =  lambda x: -4 * x +  4 * x**3 


## parameters
theta_init = np.array([0])
M = np.eye(1)
epsilon=0.1
T=10000
m=50
V = np.array([4])
C = np.array([3]) 
V_hat = np.array([4])


## true distribution
xs = np.linspace(-2,2,200)
ys = np.exp(-U(xs))
ys = (ys/sum(ys))/(xs[1]-xs[0])

# %%
# No optimization 
def sghmc_with_grad(U_grad, theta_init, M, C, V_hat, epsilon, T, m):
    """
    Stochastic Gradient Hamiltonian Monte Carlo Sampling.
    Based on Chen, Tianqi, Emily Fox, and Carlos Guestrin (2014)
    --------------------
    
    Dimensions
    -----------
    d: number of parameters
    T: length of samples
    
    Input
    ------
    U_grad: callable 
        Stochastic gradient estimates of posterior density with respect to distribution parameters 
        'U_grad_tilde(D, logp_data_grad, logp_prior_grad, mb_size, theta)' when the gradient is unknown
    
    theta_init: d-by-1 np array
        The inital sampling point
        
    M: d-by-d np array
        A mass matrix
    
    C: d-by-d np array
        A user specified friction term, should be greater than B_hat = 0.5*epsilon*V_hat 
        in the sense of in the sense of positive semi-definiteness
    
    V_hat: d-by-d np array
        Empirical Fisher information of theta
        
    epsilon: float
        Step size
    
    T: int
        Number of samples drawn from the desired distribution
        
    m: int
        Number of steps for each draw
    
    
    Output
    ------
    theta_s: T-by-d np array
        Draws sampled from the desired distrition
    
    r_s: T-by-d np array
        Draws of the momentun variables
    
    """
    d = len(theta_init)
    theta_s = np.zeros((T, d))
    r_s = np.zeros((T, d))
    theta_s[0] = theta_init
    M_inv = np.linalg.inv(M)
    B_hat = 0.5*epsilon*V_hat
    
    if d > 1:
        sd = np.linalg.cholesky(2*epsilon*(C-B_hat))
        r_s = np.random.multivariate_normal(np.zeros(d),M, size = T)
    elif d==1:
        sd = np.sqrt(2*epsilon*(C-B_hat))
        r_s = np.sqrt(M)*np.random.randn(T).reshape(T,1)
    
    for t in range(T-1):
        theta0 = theta_s[t]
        r0 = r_s[t]
        for i in range(m):
            theta0 = theta0 + epsilon*np.dot(M_inv,r0)
            r0 = r0 - epsilon*U_grad(theta0) - epsilon*np.dot(np.dot(C,M_inv),r0) +  np.dot(sd,np.random.randn(d))
        theta_s[t+1] = theta0
    
    return [theta_s,r_s]

# %%
# %load_ext cython
# Out:
# The cython extension is already loaded. To reload it, use:
#   %reload_ext cython

# %%
# %%cython -a
# import numpy as np
# import cython
# from cython.parallel import parallel, prange
#
# @cython.boundscheck(False)
# @cython.wraparound(False)
# def dot_prod(double[:,:] u, double[:,:] v):
#
#     cdef int i, j, k
#     cdef int m, n, p
#
#
#     m = u.shape[0]
#     n = u.shape[1]
#     p = v.shape[1]
#
#     res = np.zeros((m, p), dtype=np.float64)
#     cdef double[:, :] C = res
#
#     for i in range(m):
#         for j in range(p):
#             for k in range(n):
#                 C[i,j] += u[i,k] * v[k,j]
#     return res
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 0.29.22 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_343bf136bee89e2436bca8b853e64c59.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# .cython.code .error_goto  { color: #FFA000; }
#
# .cython.code .coerce  { color: #008000; border: 1px dotted #008000 }
# .cython.code .py_attr { color: #FF0000; font-weight: bold; }
# .cython.code .c_attr  { color: #0000FF; }
# .cython.code .py_call { color: #FF0000; font-weight: bold; }
# .cython.code .c_call  { color: #0000FF; }
#
# .cython.score-0 {background-color: #FFFFff;}
# .cython.score-1 {background-color: #FFFFe7;}
# .cython.score-2 {background-color: #FFFFd4;}
# .cython.score-3 {background-color: #FFFFc4;}
# .cython.score-4 {background-color: #FFFFb6;}
# .cython.score-5 {background-color: #FFFFaa;}
# .cython.score-6 {background-color: #FFFF9f;}
# .cython.score-7 {background-color: #FFFF96;}
# .cython.score-8 {background-color: #FFFF8d;}
# .cython.score-9 {background-color: #FFFF86;}
# .cython.score-10 {background-color: #FFFF7f;}
# .cython.score-11 {background-color: #FFFF79;}
# .cython.score-12 {background-color: #FFFF73;}
# .cython.score-13 {background-color: #FFFF6e;}
# .cython.score-14 {background-color: #FFFF6a;}
# .cython.score-15 {background-color: #FFFF66;}
# .cython.score-16 {background-color: #FFFF62;}
# .cython.score-17 {background-color: #FFFF5e;}
# .cython.score-18 {background-color: #FFFF5b;}
# .cython.score-19 {background-color: #FFFF57;}
# .cython.score-20 {background-color: #FFFF55;}
# .cython.score-21 {background-color: #FFFF52;}
# .cython.score-22 {background-color: #FFFF4f;}
# .cython.score-23 {background-color: #FFFF4d;}
# .cython.score-24 {background-color: #FFFF4b;}
# .cython.score-25 {background-color: #FFFF48;}
# .cython.score-26 {background-color: #FFFF46;}
# .cython.score-27 {background-color: #FFFF44;}
# .cython.score-28 {background-color: #FFFF43;}
# .cython.score-29 {background-color: #FFFF41;}
# .cython.score-30 {background-color: #FFFF3f;}
# .cython.score-31 {background-color: #FFFF3e;}
# .cython.score-32 {background-color: #FFFF3c;}
# .cython.score-33 {background-color: #FFFF3b;}
# .cython.score-34 {background-color: #FFFF39;}
# .cython.score-35 {background-color: #FFFF38;}
# .cython.score-36 {background-color: #FFFF37;}
# .cython.score-37 {background-color: #FFFF36;}
# .cython.score-38 {background-color: #FFFF35;}
# .cython.score-39 {background-color: #FFFF34;}
# .cython.score-40 {background-color: #FFFF33;}
# .cython.score-41 {background-color: #FFFF32;}
# .cython.score-42 {background-color: #FFFF31;}
# .cython.score-43 {background-color: #FFFF30;}
# .cython.score-44 {background-color: #FFFF2f;}
# .cython.score-45 {background-color: #FFFF2e;}
# .cython.score-46 {background-color: #FFFF2d;}
# .cython.score-47 {background-color: #FFFF2c;}
# .cython.score-48 {background-color: #FFFF2b;}
# .cython.score-49 {background-color: #FFFF2b;}
# .cython.score-50 {background-color: #FFFF2a;}
# .cython.score-51 {background-color: #FFFF29;}
# .cython.score-52 {background-color: #FFFF29;}
# .cython.score-53 {background-color: #FFFF28;}
# .cython.score-54 {background-color: #FFFF27;}
# .cython.score-55 {background-color: #FFFF27;}
# .cython.score-56 {background-color: #FFFF26;}
# .cython.score-57 {background-color: #FFFF26;}
# .cython.score-58 {background-color: #FFFF25;}
# .cython.score-59 {background-color: #FFFF24;}
# .cython.score-60 {background-color: #FFFF24;}
# .cython.score-61 {background-color: #FFFF23;}
# .cython.score-62 {background-color: #FFFF23;}
# .cython.score-63 {background-color: #FFFF22;}
# .cython.score-64 {background-color: #FFFF22;}
# .cython.score-65 {background-color: #FFFF22;}
# .cython.score-66 {background-color: #FFFF21;}
# .cython.score-67 {background-color: #FFFF21;}
# .cython.score-68 {background-color: #FFFF20;}
# .cython.score-69 {background-color: #FFFF20;}
# .cython.score-70 {background-color: #FFFF1f;}
# .cython.score-71 {background-color: #FFFF1f;}
# .cython.score-72 {background-color: #FFFF1f;}
# .cython.score-73 {background-color: #FFFF1e;}
# .cython.score-74 {background-color: #FFFF1e;}
# .cython.score-75 {background-color: #FFFF1e;}
# .cython.score-76 {background-color: #FFFF1d;}
# .cython.score-77 {background-color: #FFFF1d;}
# .cython.score-78 {background-color: #FFFF1c;}
# .cython.score-79 {background-color: #FFFF1c;}
# .cython.score-80 {background-color: #FFFF1c;}
# .cython.score-81 {background-color: #FFFF1c;}
# .cython.score-82 {background-color: #FFFF1b;}
# .cython.score-83 {background-color: #FFFF1b;}
# .cython.score-84 {background-color: #FFFF1b;}
# .cython.score-85 {background-color: #FFFF1a;}
# .cython.score-86 {background-color: #FFFF1a;}
# .cython.score-87 {background-color: #FFFF1a;}
# .cython.score-88 {background-color: #FFFF1a;}
# .cython.score-89 {background-color: #FFFF19;}
# .cython.score-90 {background-color: #FFFF19;}
# .cython.score-91 {background-color: #FFFF19;}
# .cython.score-92 {background-color: #FFFF19;}
# .cython.score-93 {background-color: #FFFF18;}
# .cython.score-94 {background-color: #FFFF18;}
# .cython.score-95 {background-color: #FFFF18;}
# .cython.score-96 {background-color: #FFFF18;}
# .cython.score-97 {background-color: #FFFF17;}
# .cython.score-98 {background-color: #FFFF17;}
# .cython.score-99 {background-color: #FFFF17;}
# .cython.score-100 {background-color: #FFFF17;}
# .cython.score-101 {background-color: #FFFF16;}
# .cython.score-102 {background-color: #FFFF16;}
# .cython.score-103 {background-color: #FFFF16;}
# .cython.score-104 {background-color: #FFFF16;}
# .cython.score-105 {background-color: #FFFF16;}
# .cython.score-106 {background-color: #FFFF15;}
# .cython.score-107 {background-color: #FFFF15;}
# .cython.score-108 {background-color: #FFFF15;}
# .cython.score-109 {background-color: #FFFF15;}
# .cython.score-110 {background-color: #FFFF15;}
# .cython.score-111 {background-color: #FFFF15;}
# .cython.score-112 {background-color: #FFFF14;}
# .cython.score-113 {background-color: #FFFF14;}
# .cython.score-114 {background-color: #FFFF14;}
# .cython.score-115 {background-color: #FFFF14;}
# .cython.score-116 {background-color: #FFFF14;}
# .cython.score-117 {background-color: #FFFF14;}
# .cython.score-118 {background-color: #FFFF13;}
# .cython.score-119 {background-color: #FFFF13;}
# .cython.score-120 {background-color: #FFFF13;}
# .cython.score-121 {background-color: #FFFF13;}
# .cython.score-122 {background-color: #FFFF13;}
# .cython.score-123 {background-color: #FFFF13;}
# .cython.score-124 {background-color: #FFFF13;}
# .cython.score-125 {background-color: #FFFF12;}
# .cython.score-126 {background-color: #FFFF12;}
# .cython.score-127 {background-color: #FFFF12;}
# .cython.score-128 {background-color: #FFFF12;}
# .cython.score-129 {background-color: #FFFF12;}
# .cython.score-130 {background-color: #FFFF12;}
# .cython.score-131 {background-color: #FFFF12;}
# .cython.score-132 {background-color: #FFFF11;}
# .cython.score-133 {background-color: #FFFF11;}
# .cython.score-134 {background-color: #FFFF11;}
# .cython.score-135 {background-color: #FFFF11;}
# .cython.score-136 {background-color: #FFFF11;}
# .cython.score-137 {background-color: #FFFF11;}
# .cython.score-138 {background-color: #FFFF11;}
# .cython.score-139 {background-color: #FFFF11;}
# .cython.score-140 {background-color: #FFFF11;}
# .cython.score-141 {background-color: #FFFF10;}
# .cython.score-142 {background-color: #FFFF10;}
# .cython.score-143 {background-color: #FFFF10;}
# .cython.score-144 {background-color: #FFFF10;}
# .cython.score-145 {background-colo

# %%
def sghmc_with_grad_cython(U_grad, theta_init, M, C, V_hat, epsilon, T, m):
    """
    Stochastic Gradient Hamiltonian Monte Carlo Sampling.
    Based on Chen, Tianqi, Emily Fox, and Carlos Guestrin (2014)
    --------------------
    """
    d = len(theta_init)
    C = C.reshape((d, d)).astype(float)
    theta_s = np.zeros((T, d))
    r_s = np.zeros((T, d))
    theta_s[0] = theta_init
    M_inv = np.linalg.inv(M)
    B_hat = 0.5*epsilon*V_hat

    
    if d > 1:
        sd = np.linalg.cholesky(2*epsilon*(C-B_hat))
        r_s = np.random.multivariate_normal(np.zeros(d),M, size = T)
    elif d==1:
        sd = np.sqrt(2*epsilon*(C-B_hat))
        r_s = np.sqrt(M)*np.random.randn(T).reshape(T,1)
    
    for t in range(T-1):
        theta0 = theta_s[t]
        r0 = r_s[t].reshape(1, r_s.shape[1])
        for i in range(m):
            theta0 = theta0 + epsilon*dot_prod(M_inv,r0)
            r0 = r0 - epsilon*U_grad(theta0) - epsilon*dot_prod(dot_prod(C,M_inv),r0) +  dot_prod(sd,np.random.randn(d).reshape((d, 1)))
        theta_s[t+1] = theta0
    
    return [theta_s,r_s]

# %%
# replace np.dot with @ optimization 
def sghmc_with_grad_matmul(U_grad, theta_init, M, C, V_hat, epsilon, T, m):
    """
    Stochastic Gradient Hamiltonian Monte Carlo Sampling.
    Based on Chen, Tianqi, Emily Fox, and Carlos Guestrin (2014)
    """
    d = len(theta_init)
    theta_s = np.zeros((T, d))
    r_s = np.zeros((T, d))
    theta_s[0] = theta_init
    M_inv = np.linalg.inv(M)
    B_hat = 0.5*epsilon*V_hat
    
    if d > 1:
        sd = np.linalg.cholesky(2*epsilon*(C-B_hat))
        r_s = np.random.multivariate_normal(np.zeros(d),M, size = T)
    elif d==1:
        sd = np.sqrt(2*epsilon*(C-B_hat))
        r_s = np.sqrt(M)*np.random.randn(T).reshape(T,1)
    
    for t in range(T-1):
        theta0 = theta_s[t]
        r0 = r_s[t]
        for i in range(m):
            theta0 = theta0 + epsilon*M_inv@r0
            r0 = r0 - epsilon*U_grad(theta0) - epsilon*C@M_inv@r0 + sd@np.random.randn(d)
        theta_s[t+1] = theta0
    
    return [theta_s,r_s]

# %%
# numba optimization 1: apply njit on gradient function 
def sghmc_with_grad_numba1(U_grad, theta_init, M, C, V_hat, epsilon, T, m):
    """
    Stochastic Gradient Hamiltonian Monte Carlo Sampling.
    Based on Chen, Tianqi, Emily Fox, and Carlos Guestrin (2014)
    """
    d = len(theta_init)
    theta_s = np.zeros((T, d))
    r_s = np.zeros((T, d))
    theta_s[0] = theta_init
    M_inv = np.linalg.inv(M)
    B_hat = 0.5*epsilon*V_hat
    
    if d > 1:
        sd = np.linalg.cholesky(2*epsilon*(C-B_hat))
        r_s = np.random.multivariate_normal(np.zeros(d),M, size = T)
    elif d==1:
        sd = np.sqrt(2*epsilon*(C-B_hat))
        r_s = np.sqrt(M)*np.random.randn(T).reshape(T,1)
    
    U_grad_jit = numba.vectorize(U_grad)
    
    for t in range(T-1):
        theta0 = theta_s[t]
        r0 = r_s[t]
        for i in range(m):
            theta0 = theta0 + epsilon*M_inv@r0
            r0 = r0 - epsilon*U_grad_jit(theta0) - epsilon*C@M_inv@r0 + sd@np.random.randn(d)
        theta_s[t+1] = theta0
    
    return [theta_s,r_s]

# %%
# numba optimization2: apply njit on both gradient and matrix multiplication 
def sghmc_with_grad_numba2(U_grad, theta_init, M, C, V_hat, epsilon, T, m):
    """
    Stochastic Gradient Hamiltonian Monte Carlo Sampling.
    Based on Chen, Tianqi, Emily Fox, and Carlos Guestrin (2014)
    """
    d = len(theta_init)
    theta_s = np.zeros((T, d))
    r_s = np.zeros((T, d))
    theta_s[0] = theta_init
    M_inv = np.linalg.inv(M)
    B_hat = 0.5*epsilon*V_hat
    
    if d > 1:
        sd = np.linalg.cholesky(2*epsilon*(C-B_hat))
        r_s = np.random.multivariate_normal(np.zeros(d),M, size = T)
    elif d==1:
        sd = np.sqrt(2*epsilon*(C-B_hat))
        r_s = np.sqrt(M)*np.random.randn(T).reshape(T,1)
    
    U_grad_jit = numba.njit(U_grad)
    
    @numba.njit
    def update(x,y):
        x = x + epsilon*M_inv@y
        y = y - epsilon*U_grad_jit(x) - epsilon*C@M_inv@y + sd@np.random.randn(d)
        return [x,y]
    
    for t in range(T-1):
        theta0 = theta_s[t]
        r0 = r_s[t]
        for i in range(m):
            theta0, r0 = update(theta0, r0)
        theta_s[t+1] = theta0
    
    return [theta_s,r_s]

# %%
from numba import jit, prange
from numba import int32, int64, float32, float64

# nb_inner1d = numba.jit(float64[:,:](float64[:,:], float64[:,:]), nopython = True)(dot_py)
# numba optimization3: apply vectorize on gradient calculation and njit on matrix multiplication for loops 
def sghmc_with_grad_numba3(U_grad, theta_init, M, C, V_hat, epsilon, T, m):
    """
    Stochastic Gradient Hamiltonian Monte Carlo Sampling.
    Based on Chen, Tianqi, Emily Fox, and Carlos Guestrin (2014)
    """
    d = len(theta_init)
    theta_s = np.zeros((T, d))
    r_s = np.zeros((T, d))
    theta_s[0] = theta_init
    M_inv = np.linalg.inv(M)
    B_hat = 0.5*epsilon*V_hat
    
    if d > 1:
        sd = np.linalg.cholesky(2*epsilon*(C-B_hat))
        r_s = np.random.multivariate_normal(np.zeros(d),M, size = T)
    elif d==1:
        sd = np.sqrt(2*epsilon*(C-B_hat))
        r_s = np.sqrt(M)*np.random.randn(T).reshape(T,1)
    
    # U_grad_vec = numba.jit(float64[:](float64[:]), nopython=True)(U_grad)
    U_grad_vec = numba.vectorize(U_grad)
    
    
    @numba.jit(nopython=True)
    def update(theta_s, r_s):
        for t in range(T-1):
            theta0 = theta_s[t]
            r0 = r_s[t]
            for i in range(m):
                theta0 = theta0 + epsilon*M_inv@r0
                r0 = r0 - epsilon*U_grad_vec(theta0) - epsilon*C@M_inv@r0 + sd@np.random.randn(d)
            theta_s[t+1] = theta0
        return theta_s
    
    theta_s = update(theta_s, r_s)
    
    return [theta_s,r_s]

# %%
## potential energy function
U = lambda x:  -2*x**2 + x**4
gradU =  lambda x: -4 * x +  4 * x**3 


## parameters
theta_init = np.array([0])
M = np.eye(1)
epsilon=0.1
T=10000
m=50
V = np.array([4])
C = np.array([3]) 
V_hat = np.array([4])


## true distribution
xs = np.linspace(-2,2,200)
ys = np.exp(-U(xs))
ys = (ys/sum(ys))/(xs[1]-xs[0])

# %%
# %%timeit
theta, r = sghmc_with_grad(gradU, theta_init, M, C, V_hat, epsilon, T, m)
# Out:
# 7.5 s ± 408 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
theta, r = sghmc_with_grad_cython(gradU, theta_init, M, C, V_hat, epsilon, T, m)
# Out:
# 7.22 s ± 58.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%time
theta, r =sghmc_with_grad_matmul(gradU, theta_init, M, C, V_hat, epsilon, T, m)
# Out:
# CPU times: user 7.54 s, sys: 38.4 ms, total: 7.58 s
# Wall time: 7.55 s

# %%
# %%timeit
theta, r = sghmc_with_grad_numba1(gradU, theta_init, M, C, V_hat, epsilon, T, m)
# Out:
# 6.15 s ± 527 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
theta, r = sghmc_with_grad_numba2(gradU, theta_init, M, C, V_hat, epsilon, T, m)
# Out:
# 1.54 s ± 95.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
theta, r = sghmc_with_grad_numba3(gradU, theta_init, M, C, V_hat, epsilon, T, m)
# Out:
# 908 ms ± 10.3 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %prun -q -D sghmc_with_grad.prof sghmc_with_grad(gradU, theta_init, M, C, V_hat, epsilon, T, m) 

import pstats
p = pstats.Stats('sghmc_with_grad.prof')
p.sort_stats('tottime').print_stats()
pass
# Out:
#
# *** Profile stats marshalled to file 'sghmc_with_grad.prof'.
# Mon Apr 26 13:20:10 2021    sghmc_with_grad.prof
#
#          6999330 function calls in 8.666 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    3.656    3.656    8.666    8.666 <ipython-input-2-2dedc8ff593a>:2(sghmc_with_grad)
#    499950    1.763    0.000    1.763    0.000 <ipython-input-10-aa50056b54bc>:3(<lambda>)
#   1999801    1.632    0.000    1.632    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#   1999800    0.776    0.000    2.588    0.000 <__array_function__ internals>:2(dot)
#    499951    0.659    0.000    0.659    0.000 {method 'randn' of 'numpy.random.mtrand.RandomState' objects}
#   1999800    0.180    0.000    0.180    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/multiarray.py:716(dot)
#         1    0.000    0.000    8.666    8.666 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:476(inv)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         1    0.000    0.000    8.666    8.666 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:135(_commonType)
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:107(_makearray)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(inv)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:102(get_linalg_error_extobj)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:112(isComplexType)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:125(_realType)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:199(_assert_stacked_square)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/_asarray.py:23(asarray)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:193(_assert_stacked_2d)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:472(_unary_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}

# %%
# change np.dot to @ 
# %prun -q -D sghmc_with_grad_numba3.prof sghmc_with_grad_numba3(gradU, theta_init, M, C, V_hat, epsilon, T, m) 
import pstats
p = pstats.Stats('sghmc_with_grad_numba3.prof')
p.sort_stats('tottime').print_stats()
pass
# Out:
#
# *** Profile stats marshalled to file 'sghmc_with_grad_numba3.prof'.
# Mon Apr 26 13:20:11 2021    sghmc_with_grad_numba3.prof
#
#          575065 function calls (535856 primitive calls) in 1.141 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.473    0.473    0.473    0.473 <ipython-input-9-71b7db084db7>:29(update)
#      1955    0.250    0.000    0.252    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/ffi.py:111(__call__)
#       213    0.065    0.000    0.068    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:548(_icmp)
#    112791    0.015    0.000    0.020    0.000 {built-in method builtins.isinstance}
# 14729/2758    0.014    0.000    0.021    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:313(_rec_list_vars)
# 22312/10240    0.014    0.000    0.048    0.000 {method 'format' of 'str' objects}
# 12930/5500    0.007    0.000    0.045    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/_utils.py:44(__str__)
#      3852    0.007    0.000    0.026    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:13(__init__)
# 9812/9776    0.006    0.000    0.012    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/_utils.py:54(get_reference)
#      3954    0.006    0.000    0.038    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:219(_to_string)
#      4772    0.005    0.000    0.009    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/_utils.py:24(deduplicate)
#      4702    0.004    0.000    0.021    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:212(__init__)
#      4887    0.003    0.000    0.016    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:232(_set_name)
# 3961/3737    0.003    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/abstract.py:120(__eq__)
#      1921    0.003    0.000    0.010    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/weakref.py:395(__getitem__)
#        66    0.003    0.000    0.018    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:23(compute_use_defs)
#      4887    0.003    0.000    0.013    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/_utils.py:16(register)
#      5450    0.003    0.000    0.003    0.000 {built-in method _abc._abc_instancecheck}
# 4220/3169    0.003    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/abstract.py:117(__hash__)
#      2662    0.003    0.000    0.004    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#        92    0.003    0.000    0.008    0.000 /usr/local/lib/python3.7/site-packages/numba/np/numpy_support.py:349(ufunc_find_matching_loop)
#      3852    0.003    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:338(_insert)
#   954/245    0.002    0.000    0.022    0.000 /usr/local/lib/python3.7/site-packages/numba/core/runtime/context.py:180(get_meminfos)
#      1284    0.002    0.000    0.003    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/contextlib.py:81(__init__)
#      9105    0.002    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/_utils.py:13(is_used)
#       275    0.002    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:493(__init__)
#      1586    0.002    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:120(__init__)
#      3486    0.002    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:239(_get_reference)
# 5552/4856    0.002    0.000    0.020    0.000 {built-in method builtins.next}
#      7592    0.002    0.000    0.002    0.000 {built-in method builtins.hasattr}
# 7683/7639    0.002    0.000    0.005    0.000 {method 'join' of 'str' objects}
#       999    0.002    0.000    0.012    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:944(extract_value)
#     84/72    0.002    0.000    0.094    0.001 /usr/local/lib/python3.7/site-packages/numba/core/types/functions.py:280(get_call_type)
#    132/22    0.002    0.000    0.664    0.030 /usr/local/lib/python3.7/site-packages/numba/core/compiler_machinery.py:257(_runPass)
#     15605    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#       686    0.002    0.000    0.009    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:748(store)
#        66    0.002    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:118(compute_dead_maps)
#  1284/945    0.002    0.000    0.005    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/contextlib.py:116(__exit__)
#      1150    0.002    0.000    0.002    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ctypes/__init__.py:497(cast)
#       999    0.002    0.000    0.009    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:624(__init__)
#      5450    0.002    0.000    0.004    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/abc.py:137(__instancecheck__)
# 4973/4945    0.002    0.000    0.002    0.000 {built-in method builtins.getattr}
#        24    0.002    0.000    0.006    0.000 /usr/local/lib/python3.7/site-packages/numba/core/postproc.py:175(_patch_var_dels)
#      6739    0.002    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/abstract.py:95(key)
#       213    0.002    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:309(__init__)
#      1074    0.001    0.000    0.006    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:77(__call__)
#       999    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:639(descr)
#      1293    0.001    0.000    0.002    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       165    0.001    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:65(__init__)
#  1284/936    0.001    0.000    0.014    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/contextlib.py:107(__enter__)
#       154    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:81(def_reach)
#      9133    0.001    0.000    0.001    0.000 {method 'add' of 'set' objects}
#      2715    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/utils.py:305(stream_list)
#       587    0.001    0.000    0.007    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:735(load)
# 4958/3773    0.001    0.000    0.002    0.000 {built-in method builtins.hash}
#      1312    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/np/numpy_support.py:331(ufunc_can_cast)
#       344    0.001    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:528(_rate_arguments)
#        16    0.001    0.000    0.001    0.000 {built-in method posix.getcwd}
#       223    0.001    0.000    0.014    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:362(alloca_once)
#      1795    0.001    0.000    0.011    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/manager.py:22(lookup)
# 9972/9950    0.001    0.000    0.001    0.000 {built-in method builtins.len}
# 1832/1482    0.001    0.000    0.002    0.000 {built-in method builtins.sorted}
#     12136    0.001    0.000    0.001    0.000 {method 'extend' of 'list' objects}
#       164    0.001    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:235(compute_cfg_from_blocks)
#      2418    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:30(__ne__)
#        62    0.001    0.000    0.001    0.000 {built-in method builtins.__build_class__}
#   195/147    0.001    0.000    0.268    0.002 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:321(lower_inst)
#      2715    0.001    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/templates.py:1174(new_registrations)
#      3702    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/_utils.py:71(_stringify_metadata)
# 1532/1512    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:130(_get_reference)
#        66    0.001    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/numba/core/transforms.py:239(canonicalize_cfg_single_backedge)
#       686    0.001    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:419(descr)
#       165    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:113(_descr)
#      4060    0.001    0.000    0.001    0.000 {method 'insert' of 'list' objects}
#      1284    0.001    0.000    0.004    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/contextlib.py:237(helper)
#       640    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:381(_dfs)
#       270    0.001    0.000    0.044    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:799(<listcomp>)
#       245    0.001    0.000    0.025    0.000 /usr/local/lib/python3.7/site-packages/numba/core/runtime/context.py:197(_call_incref_decref)
#      5634    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:182(block)
#       554    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeconv/typeconv.py:43(check_compatible)
#       110    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:91(liveness)
#       624    0.001    0.000    0.008    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:626(get)
#      1176    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/npytypes.py:453(key)
#      2172    0.001    0.000    0.018    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:346(list_vars)
#        45    0.001    0.000    0.006    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:578(resolve_overload)
#       252    0.001    0.000    0.008    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:865(gep)
#      2715    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/utils.py:314(sublist_iterator)
#        66    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:190(compute_live_variables)
#        66    0.001    0.000    0.041    0.001 /usr/local/lib/python3.7/site-packages/numba/core/postproc.py:68(run)
#       281    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/np/numpy_support.py:119(as_dtype)
#      1834    0.001    0.000    0.002    0.000 {method 'get' of 'dict' objects}
#       686    0.001    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:415(__init__)
#        14    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/executionengine.py:138(_find_module_ptr)
#   347/252    0.001    0.000    0.001    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pprint.py:490(_safe_repr)
#        92    0.001    0.000    0.013    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/npydecl.py:96(generic)
#     16/12    0.001    0.000    0.270    0.023 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:220(lower_block)
#       587    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:399(descr)
#        12    0.001    0.000    0.014    0.001 /usr/local/lib/python3.7/site-packages/numba/core/rewrites/registry.py:54(apply)
#       587    0.001    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:394(__init__)
#       186    0.001    0.000    0.007    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:284(if_then)
#      1026    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:1196(find_insts)
#      2249    0.001    0.000    0.001    0.000 {method 'startswith' of 'str' objects}
#      4348    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:229(_get_name)
#       446    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:268(goto_entry_block)
#      1276    0.001    0.000    0.002    0.000 <__array_function__ internals>:2(can_cast)
#      1591    0.001    0.000    0.010    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/manager.py:33(__getitem__)
#       533    0.001    0.000    0.008    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:706(getter)
#        25    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/compiler_machinery.py:341(dependency_analysis)
#       450    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:414(install_registry)
#       350    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:729(__init__)
#       273    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/base.py:361(install_registry)
#      3966    0.001    0.000    0.001    0.000 {method 'rstrip' of 'str' objects}
#       100    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:560(__repr__)
#       589    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:896(__getitem__)
#       755    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:538(__iter__)
#        83    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/packer.py:73(__init__)
#       734    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/errors.py:724(new_error_context)
#       396    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:66(fix_point_progress)
#      2138    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:116(successors)
#       677    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:503(can_convert)
#      1379    0.001    0.000    0.009    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:579(list_vars)
#       894    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:250(function_type)
#      1063    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:240(format_constant)
#       735    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/ffi.py:257(close)
#      5115    0.001    0.000    0.001    0.000 {method 'values' of 'dict' objects}
#       326    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/functions.py:77(add_error)
#  1003/951    0.001    0.000    0.003    0.000 {built-in method builtins.any}
#     70/62    0.001    0.000    0.092    0.001 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:568(resolve)
#        75    0.001    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:593(__init__)
#       170    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:394(_eliminate_dead_blocks)
#       269    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:423(wrap_constant_value)
#         1    0.001    0.001    0.001    0.001 {method 'randn' of 'numpy.random.mtrand.RandomState' objects}
#   495/305    0.001    0.000    0.031    0.000 /usr/local/lib/python3.7/site-packages/numba/core/utils.py:274(__get__)
#        96    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/npydecl.py:24(_handle_inputs)
#       119    0.001    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/module.py:45(add_metadata)
#   375/327    0.001    0.000    0.086    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/templates.py:343(apply)
#     94/61    0.001    0.000    0.010    0.000 /usr/local/lib/python3.7/site-packages/numba/core/base.py:539(get_function)
#      1955    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/ffi.py:55(__getattr__)
#      3545    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#       126    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/typeof.py:25(typeof)
#       765    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/ffi.py:267(detach)
#       275    0.000    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:899(gep)
#       275    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:515(descr)
#      1283    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:670(get_field_position)
#       873    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:558(__eq__)
#       450    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ssa.py:177(_run_ssa_block_pass)
#      1037    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x107e0cac0}
#       910    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:231(__eq__)
#       360    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:366(_add_edge)
#       636    0.000    0.000    0.000    0.000 {built-in method _functools.reduce}
#  1428/716    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/packer.py:144(rec)
#        92    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:570(_find_back_edges)
#        37    0.000    0.000    0.001    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/inspect.py:2117(_signature_from_function)
#     12/10    0.000    0.000    0.099    0.010 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:141(propagate)
#       683    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/ffi.py:300(__del__)
#       353    0.000    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:158(__setattr__)
#       254    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/ffi.py:188(close)
#   634/584    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:127(__eq__)
#       907    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/misc.py:47(unliteral)
#        70    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:496(fold_arg_vars)
#        56    0.000    0.000    0.011    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/module.py:11(parse_assembly)
#       304    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/errors.py:437(catch_warnings)
#       475    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/module.py:213(__next__)
#       213    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:325(descr)
#       6/1    0.000    0.000    0.664    0.664 /usr/local/lib/python3.7/site-packages/numba/core/compiler_machinery.py:316(run)
#       793    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:116(__init__)
#       210    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:18(wrapped)
#       113    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/interpreter.py:394(store)
#       688    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:27(as_pointer)
#       165    0.000    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:854(call)
#       225    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:717(alloca)
#        17    0.000    0.000    0.026    0.002 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:562(lower_binop)
#       184    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/np/numpy_support.py:379(choose_types)
#       225    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:475(__init__)
#       124    0.000    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:360(resolve_value_type)
#    200/83    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/packer.py:175(rec)
#    396/66    0.000    0.000    0.662    0.010 /usr/local/lib/python3.7/site-packages/numba/core/compiler_machinery.py:261(check)
#        84    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:653(_find_loops)
#       350    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:683(__init__)
#        32    0.000    0.000    0.006    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:33(_get_ll_pointer_type)
#       263    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/value.py:143(name)
#      1826    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:69(<genexpr>)
#       999    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:640(<listcomp>)
#     38/37    0.000    0.000    0.002    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/inspect.py:2198(_signature_from_callable)
#        10    0.000    0.000    0.000    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ctypes/__init__.py:47(create_string_buffer)
#       488    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:251(goto_block)
#         6    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#      1588    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#       702    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/ffi.py:250(__init__)
#       718    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:228(position_at_end)
#       370    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:173(__eq__)
#       270    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:779(__init__)
#       224    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:167(descr)
#       719    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:379(__getattr__)
#        53    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:177(set_weights)
#       270    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:344(_set_terminator)
#       545    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:681(get_type)
#        43    0.000    0.000    0.012    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:99(__init__)
#        87    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:712(<listcomp>)
#      1326    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:124(predecessors)
#     135/1    0.000    0.000    0.666    0.666 /usr/local/lib/python3.7/site-packages/numba/core/compiler_lock.py:29(_acquire_compile_lock)
#       252    0.000    0.000    0.008    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:858(gep_inbounds)
#       210    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:30(descr)
#       459    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/containers.py:243(key)
#        91    0.000    0.000    0.022    0.000 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:1258(storevar)
#       270    0.000    0.000    0.044    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:797(descr)
#        19    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/pythonapi.py:168(__init__)
#       270    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:619(append_basic_block)
#         1    0.000    0.000    1.141    1.141 <ipython-input-9-71b7db084db7>:6(sghmc_with_grad_numba3)
#       134    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:493(traverse)
#       207    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/value.py:206(is_declaration)
#        87    0.000    0.000    0.011    0.000 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:1282(delvar)
#       350    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:716(_to_list)
#      1283    0.000    0.000    0.000    0.000 {method 'index' of 'tuple' objects}
#       399    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:444(elements)
#       414    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:182(__hash__)
#       140    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:839(__init__)
#         6    0.000    0.000    0.003    0.001 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:78(run)
#       287    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/base.py:492(get_value_type)
#       276    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:236(fixup)
#       132    0.000    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:71(fix_point)
#      1444    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/compiler.py:269(__getattr__)
#       755    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:527(__init__)
#        99    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/typeof.py:60(_typeof_buffer)
#   135/133    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/abstract.py:60(__call__)
#        92    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/cffi/api.py:952(_builtin_function_type)
#       505    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/functions.py:229(_unlit_non_poison)
#       924    0.000    0.000    0.000    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/logging/__init__.py:1356(debug)
#       250    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/module.py:244(_next)
#       182    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:847(__str__)
#        90    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:467(__init__)
#       133    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:1185(find_exprs)
#      1014    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/templates.py:355(<genexpr>)
#    161/62    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/packer.py:123(_assign_names)
#       115    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:1077(add_type)
#        92    0.000    0.000    0.014    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/npydecl.py:171(generic)
#       134    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:651(__init__)
#        99    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/typeof.py:39(typeof_impl)
#       186    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/templates.py:179(signature)
#       152    0.000    0.000    0.000    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/warnings.py:470(__enter__)
#       456    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/value.py:81(__init__)
#       114    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir_utils.py:2106(enforce_no_dels)
#       275    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:516(<listcomp>)
#       532    0.000    0.000    0.001    0.000 {built-in method builtins.all}
#        24    0.000    0.000    0.013    0.001 /usr/local/lib/python3.7/site-packages/numba/core/callconv.py:547(call_function)
#       6/2    0.000    0.000    0.552    0.276 /usr/local/lib/python3.7/site-packages/numba/core/typed_passes.py:349(run_pass)
#       170    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:87(__init__)
#    151/14    0.000    0.000    0.003    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pprint.py:154(_format)
#        75    0.000    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:631(descr_prototype)
#       134    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:954(insert_value)
#      1784    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#       356    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#       270    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:163(__init__)
#        45    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:686(load_additional_registries)
#        16    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/inline_closurecall.py:1317(_inline_const_arraycall)
#      2005    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#       560    0.000    0.000    0.000    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/enum.py:356(__getitem__)
#        39    0.000    0.000    0.007    0.000 /usr/local/lib/python3.7/site-packages/numba/core/base.py:266(refresh)
#        16    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:1229(dump)
#        39    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cpu.py:65(load_additional_registries)
#         4    0.000    0.000    0.182    0.046 /usr/local/lib/python3.7/site-packages/numba/np/ufunc/array_exprs.py:329(_lower_array_expr)
#       381    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:262(typeof)
#       275    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:748(__str__)
#       256    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#     84/62    0.000    0.000    0.089    0.001 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:231(_resolve_user_function_type)
#       132    0.000    0.000    0.000    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/inspect.py:2467(__init__)
#       225    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/module.py:233(_next)
#         6    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/arrayprint.py:890(fillFormat)
#       554    0.000    0.000    0.000    0.000 {built-in method numba.core.typeconv._typeconv.check_compatible}
#     91/67    0.000    0.000    0.230    0.003 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:492(lower_assign)
#       396    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/compiler_machinery.py:24(__exit__)
#   625/624    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:121(_to_string)
#       134    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:669(descr)
#     43/31    0.000    0.000    0.218    0.007 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:997(lower_expr)
#       684    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#        99    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/cffi/api.py:194(typeof)
#       557    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:205(__new__)
#       557    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:191(function)
#        42    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/common.py:48(__init__)
#       550    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/compiler_machinery.py:400(is_registered)
#        90    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:479(descr)
#        87    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:705(traverse)
#        81    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/module.py:52(__init__)
#        10    0.000    0.000    0.021    0.002 /usr/local/lib/python3.7/site-packages/numba/core/codegen.py:563(_optimize_functions)
#        66    0.000    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:60(compute_live_map)
#       224    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:169(<listcomp>)
#        92    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/numpy_support.py:269(supported_ufunc_loop)
#       192    0.000    0.000    0.000    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/os.py:676(__getitem__)
#      1287    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/templates.py:46(args)
#        60    0.000    0.000    0.025    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:684(__call__)
#        89    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/errors.py:478(__init__)
#         4    0.000    0.000    0.022    0.005 /usr/local/lib/python3.7/site-packages/numba/np/npyimpl.py:230(_build_array)
#        88    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/misc.py:56(literal)
#       262    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:593(push_state)
#        24    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/callconv.py:454(_get_return_status)
#   124/114    0.000    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir_utils.py:1445(guard)
#       420    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#       138    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:248(_get_attribute_templates)
#       202    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:200(fix_point_progress)
#       108    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:260(dispatch)
#       127    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/ffi.py:183(__init__)
#       124    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/_utils.py:9(__init__)
#       165    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:456(__init__)
#       185    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:441(_lookup_global)
#       107    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:1165(check_var)
#       705    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#        12    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir_utils.py:1466(build_definitions)
#      1369    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:40(<genexpr>)
#       119    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/module.py:21(_fix_metadata_operands)
#       247    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:533(add)
#       396    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/compiler_machinery.py:20(__enter__)
#        84    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:103(traverse_types)
#       185    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:1251(loadvar)
#       270    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#        95    0.000    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:173(__setitem__)
#        66    0.000    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/numba/core/postproc.py:45(livemap)
#       152    0.000    0.000    0.000    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/warnings.py:181(_add_filter)
#       282    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/numpy_support.py:85(from_dtype)
#        56    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/context.py:8(get_global_context)
#        49    0.000    0.000    0.050    0.001 /usr/local/lib/python3.7/site-packages/llvmlite/ir/module.py:212(<listcomp>)
#       134    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:496(<listcomp>)
#       104    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:1171(append)
#         6    0.000    0.000    0.006    0.001 /usr/local/lib/python3.7/site-packages/numba/core/inline_closurecall.py:69(run)
#       358    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:687(__init__)
#         6    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typed_passes.py:491(run_pass)
#       135    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/abstract.py:48(_intern)
#         6    0.000    0.000    0.011    0.002 /usr/local/lib/python3.7/site-packages/numba/core/interpreter.py:102(interpret)
#       247    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/functions.py:295(<listcomp>)
#       407    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/compiler_machinery.py:403(get)
#        89    0.000    0.000    0.009    0.000 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:1301(alloca_lltype)
#       165    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:114(<listcomp>)
#       143    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/compiler_machinery.py:177(_validate_pass)
#       152    0.000    0.000    0.000    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/warnings.py:489(__exit__)
#       360    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:101(add_edge)
#        66    0.000    0.000    0.009    0.000 /usr/local/lib/python3.7/site-packages/numba/core/postproc.py:51(deadmaps)
#         4    0.000    0.000    0.002    0.001 /usr/local/lib/python3.7/site-packages/numba/core/ssa.py:154(_run_block_rewrite)
#       111    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:813(cbranch)
#        10    0.000    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:179(populate_array)
#       270    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:813(_format_name)
#       126    0.000    0.000    0.003    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/functools.py:835(wrapper)
#         5    0.000    0.000    0.100    0.020 /usr/local/lib/python3.7/site-packages/numba/np/npyimpl.py:332(numpy_ufunc_kernel)
#       252    0.000    0.000    0.002    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pprint.py:391(_repr)
#       165    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/module.py:138(add_global)
#        18    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:503(_find_dominators_internal)
#       181    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:198(module)
#       239    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:235(append_basic_block)
#        98    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/templates.py:669(_get_impl)
#       178    0.000    0.000    0.018    0.000 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:1321(decref)
#        49    0.000    0.000    0.051    0.001 /usr/local/lib/python3.7/site-packages/llvmlite/ir/module.py:233(__repr__)
#        49    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:1607(typeof_expr)
#       225    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:481(descr)
#        18    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir_utils.py:488(remove_dels)
#         6    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir_utils.py:1926(raise_on_unsupported_feature)
#       104    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/interpreter.py:369(_dispatch)
#       617    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:529(get_value_type)
#       449    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:48(get_argument_type)
#       110    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/interpreter.py:179(_iter_inst)
#       263    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/compiler_machinery.py:356(resolve_requires)
#       564    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:251(__hash__)
#       178    0.000    0.000    0.010    0.000 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:1234(_alloca_var)
#        24    0.000    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/numba/core/callconv.py:490(decorate_function)
#       113    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:805(branch)
#       192    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/utils.py:253(__setitem__)
#        93    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:1434(typeof_assign)
#        30    0.000    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/linker.py:5(link_modules)
#       203    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/inline_closurecall.py:1451(list_var_used)
#        49    0.000    0.000    0.050    0.001 /usr/local/lib/python3.7/site-packages/llvmlite/ir/module.py:207(_get_body_lines)
#      1030    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       103    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:170(__init__)
#      1082    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:246(wrap_constant_value)
#       470    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:94(add_node)
#        31    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/callconv.py:409(check_try_status)
#       152    0.000    0.000    0.001    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/warnings.py:165(simplefilter)
#      1276    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/multiarray.py:478(can_cast)
#       6/2    0.000    0.000    0.553    0.276 /usr/local/lib/python3.7/site-packages/numba/core/typed_passes.py:437(run_pass)
#       924    0.000    0.000    0.000    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/logging/__init__.py:1614(isEnabledFor)
#        66    0.000    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/numba/core/transforms.py:309(canonicalize_cfg)
#       126    0.000    0.000    0.000    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/functools.py:781(dispatch)
#        42    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/npytypes.py:418(__init__)
#       765    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:1239(terminator)
#       130    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:1077(define)
#       220    0.000    0.000    0.001    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/_collections_abc.py:742(__iter__)
#       153    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:53(add_type)
# ...
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:112(isComplexType)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:343(format_constant)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/utils.py:191(unset)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/containers.py:282(is_types_iterable)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/common.py:20(iterator_type)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/errors.py:172(code)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/errors.py:178(filename)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/functions.py:469(_get_object)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:460(on_disposal)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/templates.py:745(get_impl_key)
#         1    0.000    0.000    0.000    0.000 {built-in method numba.core.typeconv._typeconv.get_pointer}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:37(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:292(_get_ptr_by_index)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:383(alloca_once_value)
#        12    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:605(<lambda>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:34(__init__)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:182(get_value_type)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:499(inner_models)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:453(pair_first)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:989(infer_constant)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/pythonapi.py:109(__init__)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/pythonapi.py:202(get_env_manager)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/pythonapi.py:332(err_write_unraisable)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/pythonapi.py:1161(make_none)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/pythonapi.py:1270(alloca_obj)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/llvmpy/core.py:89(struct)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:696(<listcomp>)
#         6    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/debuginfo.py:55(mark_subprogram)
#         6    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/debuginfo.py:61(finalize)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/funcdesc.py:123(llvm_cfunc_wrapper_name)
#         1    0.000    0.000    0.666    0.666 /usr/local/lib/python3.7/site-packages/numba/core/dispatcher.py:76(compile)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/dispatcher.py:118(_get_implementation)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/dispatcher.py:172(__init__)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/dispatcher.py:229(_compilation_chain_init_hook)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/dispatcher.py:243(_make_finalizer)
#         5    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/interpreter.py:1114(op_BINARY_SUBTRACT)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/interpreter.py:1132(op_BINARY_POWER)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/interpreter.py:1368(op_LOAD_METHOD)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/interpreter.py:1371(op_CALL_METHOD)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:292(op_LOAD_ATTR)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:739(op_STORE_SUBSCR)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:1027(op_LOAD_METHOD)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:1084(__eq__)
#        16    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:1120(blockstack_initial)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:1179(peek)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:1198(reset_stack)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/base.py:199(enable_boundscheck)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/base.py:1110(get_preferred_array_alignment)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:124(load_item)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:133(store_item)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:172(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:612(__init__)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:649(loop_tail)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:677(get_index_bounds)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:681(loop_head)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:968(get_shape)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:1275(<listcomp>)
#         6    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:135(__init__)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:538(_is_array_not_precise)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:733(_refine_target_type)
#         1    0.000    0.000    0.001    0.001 /usr/local/lib/python3.7/site-packages/numba/core/callwrapper.py:66(emit_cleanup)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/callwrapper.py:209(_simplified_return_type)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/codegen.py:544(codegen)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/inline_closurecall.py:116(<lambda>)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/caching.py:98(save_overload)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/ufunc/ufuncbuilder.py:191(parse_identity)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/ufunc/wrappers.py:125(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/ufunc/wrappers.py:124(load)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/ufunc/dufunc.py:133(nin)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/ufunc/dufunc.py:319(<listcomp>)
#         1    0.000    0.000    0.002    0.002 /usr/local/lib/python3.7/site-packages/numba/np/linalg.py:480(dot_2_mv)
#         6    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/npyimpl.py:45(update_indices)
#         6    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/npyimpl.py:48(as_values)
#         5    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/npyimpl.py:325(_pack_output_values)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.globals}
#         1    0.000    0.000    0.000    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/collections/__init__.py:570(__missing__)
#         1    0.000    0.000    0.000    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/inspect.py:90(ismethoddescriptor)
#         1    0.000    0.000    0.000    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/inspect.py:276(isbuiltin)
#         1    0.000    0.000    0.000    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/inspect.py:2525(annotation)
#         1    0.000    0.000    0.000    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/inspect.py:2839(return_annotation)
#         8    0.000    0.000    0.000    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pickle.py:196(end_framing)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {method 'from_address' of '_ctypes.PyCArrayType' objects}
#         1    0.000    0.000    0.000    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:472(_unary_dispatcher)
#         5    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:615(basic_blocks)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/containers.py:362(<genexpr>)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/errors.py:181(indicate)
#         8    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:146(init)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:480(insert_global)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:415(is_null)
#         5    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:239(as_return)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:447(get_data_type)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:714(inner_models)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:959(infer_constant)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir_utils.py:398(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir_utils.py:400(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:1226(clear)
#         6    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/debuginfo.py:46(__init__)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/dispatcher.py:121(_customize_flags)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/dispatcher.py:211(<genexpr>)
#         6    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/interpreter.py:440(op_NOP)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:725(op_POP_BLOCK)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:1030(op_CALL_METHOD)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:1176(get_tos)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:1192(push_block)
#         6    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/bytecode.py:168(__iter__)
#         6    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/callconv.py:343(_make_call_helper)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/base.py:338(nonconst_module_attrs)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:630(get_shape)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:668(prepare)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:674(get_shape)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:684(loop_tail)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:1148(extents_may_overlap)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:1274(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:1406(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:779(get_call_signature)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cpu.py:243(<lambda>)
#         6    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/compiler_machinery.py:245(finalized)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/caching.py:95(load_overload)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/ufunc/wrappers.py:129(store)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/cpython/numbers.py:198(_get_power_zerodiv_return)
#         6    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/npyimpl.py:82(load_data)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/npyimpl.py:88(return_val)
#         1    0.000    0.000    0.000    0.000 <ipython-input-9-71b7db084db7>:1(<module>)

# %% [markdown]
# ### Optimization for sghmc algorithm with data and likelihood function

# %%
def U_grad_tilde(theta, data, logp_data_grad, logp_prior_grad, mb_size):
    """
    Stochastic gradient estimates of posterior density with respect to distribution parameters
    Based on a minibatch D_hat sampled uniformly at random from D
    ------------------------
    
    Dimensions
    -----------
    n: number of observations from the data
    m: dimension of the data

    Input
    -----
    D: n-by-m np array
        Dataset
        
    logp_data_grad: callable 'logp_data_grad(data, theta)'
        Gradient of likelihood of the data with respect to distribution parameters
    
    logp_prior_grad: callable 'logp_prior_grad(theta)'
        Gradient of prior with respect to distribution parameters
    
    mb_size: int
        Size of the minibatch
    
    theta: d-by-1 np array
        Distribution parameters
    
    Output
    -----
    U_tilde: d-by-1 np array
        Stochastic gradient estimates of posterior density with respect to distribution parameters
    """
    n = data.shape[0]
    data_hat = data[np.random.choice(range(n), size = mb_size, replace = False)]
    U_tilde = -(n/mb_size)*logp_data_grad(data_hat, theta) - logp_prior_grad(theta)
    return U_tilde

# %%
logp_prior_grad = lambda theta: -theta # prior N(0,1)

def logp_data_grad(data, theta):
    """
    log likelihood of a linear regression 
    --------------
    
    Assume that the first column of the data is the predicted variable
    """
    X = data[:,1:]
    y = data[:,0]
    return X.T@y - X.T@X@theta

# %%
def sghmc_with_data(data, logp_data_grad, logp_prior_grad, mb_size, theta_init, M, C, V_hat, epsilon, T, m):
    """
    Stochastic Gradient Hamiltonian Monte Carlo Sampling.
    Based on Chen, Tianqi, Emily Fox, and Carlos Guestrin (2014)
    """
    d = theta_init.shape[0]
    theta_s = np.zeros((T, d))
    r_s = np.zeros((T, d))
    theta_s[0] = theta_init
    M_inv = np.linalg.inv(M)
    B_hat = 0.5*epsilon*V_hat
    
    
    n = data.shape[0]
    data_hat = data[np.random.choice(range(n), size = mb_size, replace = False)]
    
    if d > 1:
        sd = np.linalg.cholesky(2*epsilon*(C-B_hat))
        r_s = np.random.multivariate_normal(np.zeros(d),M, size = T)
    elif d==1:
        sd = np.sqrt(2*epsilon*(C-B_hat))
        r_s = np.sqrt(M)*np.random.randn(T).reshape(T,1)

    
    for t in range(T-1):
        theta0 = theta_s[t]
        r0 = r_s[t]
        for i in range(m):
            theta0 = theta0 + epsilon*M_inv@r0
            r0 = r0 + epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0) +logp_prior_grad(theta0)) - epsilon*C@M_inv@r0 + sd@np.random.randn(d)
        theta_s[t+1] = theta0
    
    return [theta_s,r_s]

# %%
def sghmc_with_data_cython(data, logp_data_grad, logp_prior_grad, mb_size, theta_init, M, C, V_hat, epsilon, T, m):
    """
    Stochastic Gradient Hamiltonian Monte Carlo Sampling.
    Based on Chen, Tianqi, Emily Fox, and Carlos Guestrin (2014)
    """
    d = theta_init.shape[0]
    theta_s = np.zeros((T, d))
    r_s = np.zeros((T, d))
    theta_s[0] = theta_init
    M_inv = np.linalg.inv(M)
    B_hat = 0.5*epsilon*V_hat
    
    
    n = data.shape[0]
    data_hat = data[np.random.choice(range(n), size = mb_size, replace = False)]
    
    if d > 1:
        sd = np.linalg.cholesky(2*epsilon*(C-B_hat))
        r_s = np.random.multivariate_normal(np.zeros(d),M, size = T)
    elif d==1:
        sd = np.sqrt(2*epsilon*(C-B_hat))
        r_s = np.sqrt(M)*np.random.randn(T).reshape(T,1)

    
    for t in range(T-1):
        theta0 = theta_s[t]
        r0 = r_s[t]
        for i in range(1):
            print((epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0))).shape)
            theta0 = theta0 + epsilon*dot_prod(M_inv,r0)
            
            print(r0.shape)
            r0 = r0 + epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0) +logp_prior_grad(theta0)) - epsilon*dot_prod(dot_prod(C,M_inv),r0) + dot_prod(sd,np.random.randn(d).reshape((d, 1)))
            
        print(theta_s.shape, theta0.shape)
        theta_s[t+1] = theta0
    
    return [theta_s,r_s]

# %%
def sghmc_with_data_numba(data, logp_data_grad, logp_prior_grad, mb_size, theta_init, M, C, V_hat, epsilon, T, m):
    """
    Stochastic Gradient Hamiltonian Monte Carlo Sampling.
    Based on Chen, Tianqi, Emily Fox, and Carlos Guestrin (2014)
    """
    d = theta_init.shape[0]
    theta_s = np.zeros((T, d))
    r_s = np.zeros((T, d))
    theta_s[0] = theta_init
    M_inv = np.linalg.inv(M)
    B_hat = 0.5*epsilon*V_hat
    
    
    logp_data_grad_jit = numba.njit(logp_data_grad)
    logp_prior_grad_jit = numba.njit(logp_prior_grad)
    
    n = data.shape[0]
    data_hat = data[np.random.choice(range(n), size = mb_size, replace = False)]
    
    if d > 1:
        sd = np.linalg.cholesky(2*epsilon*(C-B_hat))
        r_s = np.random.multivariate_normal(np.zeros(d),M, size = T)
    elif d==1:
        sd = np.sqrt(2*epsilon*(C-B_hat))
        r_s = np.sqrt(M)*np.random.randn(T).reshape(T,1)
    
    @numba.njit
    def update(x,y):
        x = x + epsilon*M_inv@y
        y = y + epsilon*((n/mb_size)*logp_data_grad_jit(data_hat, x) +logp_prior_grad_jit(x)) - epsilon*C@M_inv@y + sd@np.random.randn(d)
        return [x,y]
    
    
    for t in range(T-1):
        theta0 = theta_s[t]
        r0 = r_s[t]
        for i in range(m):
            theta0, r0 = update(theta0, r0)
        theta_s[t+1] = theta0
    
    return [theta_s,r_s]

# %%
def sghmc_with_data_numba2(data, logp_data_grad, logp_prior_grad, mb_size, theta_init, M, C, V_hat, epsilon, T, m):
    """
    Stochastic Gradient Hamiltonian Monte Carlo Sampling.
    Based on Chen, Tianqi, Emily Fox, and Carlos Guestrin (2014)
    """
    d = theta_init.shape[0]
    theta_s = np.zeros((T, d))
    r_s = np.zeros((T, d))
    theta_s[0] = theta_init
    M_inv = np.linalg.inv(M)
    B_hat = 0.5*epsilon*V_hat
    
    n = data.shape[0]
    data_hat = data[np.random.choice(range(n), size = mb_size, replace = False)]
    
    if d > 1:
        sd = np.linalg.cholesky(2*epsilon*(C-B_hat))
        r_s = np.random.multivariate_normal(np.zeros(d),M, size = T)
    elif d==1:
        sd = np.sqrt(2*epsilon*(C-B_hat))
        r_s = np.sqrt(M)*np.random.randn(T).reshape(T,1) 
        
    logp_data_grad = numba.njit(logp_data_grad)
    logp_prior_grad = numba.njit(logp_prior_grad)
        
    
    @numba.jit(nopython=True)
    def update(theta_s, r_s):
        for t in range(T-1):
            theta0 = theta_s[t]
            r0 = r_s[t]
            for i in range(m):
                theta0 = theta0 + epsilon*M_inv@r0
                r0 = r0 + epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0) +logp_prior_grad(theta0)) - epsilon*C@M_inv@r0 + sd @ np.random.randn(d)
            theta_s[t+1] = theta0
        
        return theta_s
    
    theta_s = update(theta_s, r_s)
    
    return [theta_s,r_s]

# %%
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
p = 5
true_theta = np.arange(p)
size = 10000
X = np.random.randn(size,p)
y = np.dot(X,true_theta) + np.random.randn(size)
data = np.c_[y,X]


theta_init = np.zeros(p)
M = np.eye(p)
C = 13*np.eye(p)
V_hat = 0
T = 10000
m = 50
epsilon = 0.0001
mb_size=1000 # size of minibatch

# %%
gradU = partial(U_grad_tilde, data=data, logp_data_grad=logp_data_grad, logp_prior_grad=logp_prior_grad, mb_size=1000)

# %%
# %%timeit
theta, r = sghmc_with_data(data, logp_data_grad, logp_prior_grad, mb_size, theta_init, M, C, V_hat, epsilon, T, m)
# Out:
# 12.8 s ± 258 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
theta, r = sghmc_with_data_cython(data, logp_data_grad, logp_prior_grad, mb_size, theta_init, M, C, V_hat, epsilon, T, m)

# %%
# %%timeit
theta, r = sghmc_with_data_numba(data, logp_data_grad, logp_prior_grad, mb_size, theta_init, M, C, V_hat, epsilon, T, m)
# Out:
# <ipython-input-26-79b145486053>:30: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 1d, A))
#   y = y + epsilon*((n/mb_size)*logp_data_grad_jit(data_hat, x) +logp_prior_grad_jit(x)) - epsilon*C@M_inv@y + sd@np.random.randn(d)
# <ipython-input-26-79b145486053>:30: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 2d, A))
#   y = y + epsilon*((n/mb_size)*logp_data_grad_jit(data_hat, x) +logp_prior_grad_jit(x)) - epsilon*C@M_inv@y + sd@np.random.randn(d)
# <ipython-input-26-79b145486053>:30: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 1d, A))
#   y = y + epsilon*((n/mb_size)*logp_data_grad_jit(data_hat, x) +logp_prior_grad_jit(x)) - epsilon*C@M_inv@y + sd@np.random.randn(d)
# <ipython-input-26-79b145486053>:30: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 2d, A))
#   y = y + epsilon*((n/mb_size)*logp_data_grad_jit(data_hat, x) +logp_prior_grad_jit(x)) - epsilon*C@M_inv@y + sd@np.random.randn(d)
# <ipython-input-26-79b145486053>:30: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 1d, A))
#   y = y + epsilon*((n/mb_size)*logp_data_grad_jit(data_hat, x) +logp_prior_grad_jit(x)) - epsilon*C@M_inv@y + sd@np.random.randn(d)
# <ipython-input-26-79b145486053>:30: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 2d, A))
#   y = y + epsilon*((n/mb_size)*logp_data_grad_jit(data_hat, x) +logp_prior_grad_jit(x)) - epsilon*C@M_inv@y + sd@np.random.randn(d)
# <ipython-input-26-79b145486053>:30: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 1d, A))
#   y = y + epsilon*((n/mb_size)*logp_data_grad_jit(data_hat, x) +logp_prior_grad_jit(x)) - epsilon*C@M_inv@y + sd@np.random.randn(d)
# <ipython-input-26-79b145486053>:30: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 2d, A))
#   y = y + epsilon*((n/mb_size)*logp_data_grad_jit(data_hat, x) +logp_prior_grad_jit(x)) - epsilon*C@M_inv@y + sd@np.random.randn(d)
# <ipython-input-26-79b145486053>:30: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 1d, A))
#   y = y + epsilon*((n/mb_size)*logp_data_grad_jit(data_hat, x) +logp_prior_grad_jit(x)) - epsilon*C@M_inv@y + sd@np.random.randn(d)
# <ipython-input-26-79b145486053>:30: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 2d, A))
#   y = y + epsilon*((n/mb_size)*logp_data_grad_jit(data_hat, x) +logp_prior_grad_jit(x)) - epsilon*C@M_inv@y + sd@np.random.randn(d)
# <ipython-input-26-79b145486053>:30: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 1d, A))
#   y = y + epsilon*((n/mb_size)*logp_data_grad_jit(data_hat, x) +logp_prior_grad_jit(x)) - epsilon*C@M_inv@y + sd@np.random.randn(d)
# <ipython-input-26-79b145486053>:30: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 2d, A))
#   y = y + epsilon*((n/mb_size)*logp_data_grad_jit(data_hat, x) +logp_prior_grad_jit(x)) - epsilon*C@M_inv@y + sd@np.random.randn(d)
# <ipython-input-26-79b145486053>:30: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 1d, A))
#   y = y + epsilon*((n/mb_size)*logp_data_grad_jit(data_hat, x) +logp_prior_grad_jit(x)) - epsilon*C@M_inv@y + sd@np.random.randn(d)
# <ipython-input-26-79b145486053>:30: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 2d, A))
#   y = y + epsilon*((n/mb_size)*logp_data_grad_jit(data_hat, x) +logp_prior_grad_jit(x)) - epsilon*C@M_inv@y + sd@np.random.randn(d)
# <ipython-input-26-79b145486053>:30: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 1d, A))
#   y = y + epsilon*((n/mb_size)*logp_data_grad_jit(data_hat, x) +logp_prior_grad_jit(x)) - epsilon*C@M_inv@y + sd@np.random.randn(d)
# <ipython-input-26-79b145486053>:30: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 2d, A))
#   y = y + epsilon*((n/mb_size)*logp_data_grad_jit(data_hat, x) +logp_prior_grad_jit(x)) - epsilon*C@M_inv@y + sd@np.random.randn(d)
# 12.4 s ± 205 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
theta, r = sghmc_with_data_numba2(data, logp_data_grad, logp_prior_grad, mb_size, theta_init, M, C, V_hat, epsilon, T, m)
# Out:
# <ipython-input-27-b84874ee8ecd>:34: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 1d, A))
#   r0 = r0 + epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0) +logp_prior_grad(theta0)) - epsilon*C@M_inv@r0 + sd @ np.random.randn(d)
# <ipython-input-27-b84874ee8ecd>:34: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 2d, A))
#   r0 = r0 + epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0) +logp_prior_grad(theta0)) - epsilon*C@M_inv@r0 + sd @ np.random.randn(d)
# <ipython-input-27-b84874ee8ecd>:34: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 1d, A))
#   r0 = r0 + epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0) +logp_prior_grad(theta0)) - epsilon*C@M_inv@r0 + sd @ np.random.randn(d)
# <ipython-input-27-b84874ee8ecd>:34: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 2d, A))
#   r0 = r0 + epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0) +logp_prior_grad(theta0)) - epsilon*C@M_inv@r0 + sd @ np.random.randn(d)
# <ipython-input-27-b84874ee8ecd>:34: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 1d, A))
#   r0 = r0 + epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0) +logp_prior_grad(theta0)) - epsilon*C@M_inv@r0 + sd @ np.random.randn(d)
# <ipython-input-27-b84874ee8ecd>:34: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 2d, A))
#   r0 = r0 + epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0) +logp_prior_grad(theta0)) - epsilon*C@M_inv@r0 + sd @ np.random.randn(d)
# <ipython-input-27-b84874ee8ecd>:34: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 1d, A))
#   r0 = r0 + epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0) +logp_prior_grad(theta0)) - epsilon*C@M_inv@r0 + sd @ np.random.randn(d)
# <ipython-input-27-b84874ee8ecd>:34: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 2d, A))
#   r0 = r0 + epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0) +logp_prior_grad(theta0)) - epsilon*C@M_inv@r0 + sd @ np.random.randn(d)
# <ipython-input-27-b84874ee8ecd>:34: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 1d, A))
#   r0 = r0 + epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0) +logp_prior_grad(theta0)) - epsilon*C@M_inv@r0 + sd @ np.random.randn(d)
# <ipython-input-27-b84874ee8ecd>:34: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 2d, A))
#   r0 = r0 + epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0) +logp_prior_grad(theta0)) - epsilon*C@M_inv@r0 + sd @ np.random.randn(d)
# <ipython-input-27-b84874ee8ecd>:34: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 1d, A))
#   r0 = r0 + epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0) +logp_prior_grad(theta0)) - epsilon*C@M_inv@r0 + sd @ np.random.randn(d)
# <ipython-input-27-b84874ee8ecd>:34: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 2d, A))
#   r0 = r0 + epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0) +logp_prior_grad(theta0)) - epsilon*C@M_inv@r0 + sd @ np.random.randn(d)
# <ipython-input-27-b84874ee8ecd>:34: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 1d, A))
#   r0 = r0 + epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0) +logp_prior_grad(theta0)) - epsilon*C@M_inv@r0 + sd @ np.random.randn(d)
# <ipython-input-27-b84874ee8ecd>:34: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 2d, A))
#   r0 = r0 + epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0) +logp_prior_grad(theta0)) - epsilon*C@M_inv@r0 + sd @ np.random.randn(d)
# <ipython-input-27-b84874ee8ecd>:34: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 1d, A))
#   r0 = r0 + epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0) +logp_prior_grad(theta0)) - epsilon*C@M_inv@r0 + sd @ np.random.randn(d)
# <ipython-input-27-b84874ee8ecd>:34: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 2d, A))
#   r0 = r0 + epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0) +logp_prior_grad(theta0)) - epsilon*C@M_inv@r0 + sd @ np.random.randn(d)
# 11.5 s ± 129 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %prun -q -D sghmc_with_data.prof sghmc_with_data(data, logp_data_grad, logp_prior_grad, mb_size, theta_init, M, C, V_hat, epsilon, T, m)
import pstats
p = pstats.Stats('sghmc_with_data.prof')
p.sort_stats('tottime').print_stats()
pass
# Out:
#
# *** Profile stats marshalled to file 'sghmc_with_data.prof'.
# Mon Apr 26 21:39:05 2021    sghmc_with_data.prof
#
#          1500001 function calls (1499996 primitive calls) in 13.530 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    499950    7.077    0.000    7.077    0.000 <ipython-input-114-b807f05dee81>:3(logp_data_grad)
#         1    5.373    5.373   13.530   13.530 <ipython-input-115-99b375c79739>:1(sghmc_with_data)
#    499950    0.849    0.000    0.849    0.000 {method 'randn' of 'numpy.random.mtrand.RandomState' objects}
#    499950    0.226    0.000    0.226    0.000 <ipython-input-114-b807f05dee81>:1(<lambda>)
#         1    0.002    0.002    0.003    0.003 {method 'multivariate_normal' of 'numpy.random.mtrand.RandomState' objects}
#         1    0.002    0.002    0.002    0.002 {method 'choice' of 'numpy.random.mtrand.RandomState' objects}
#      12/7    0.000    0.000    0.001    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         1    0.000    0.000   13.530   13.530 <string>:1(<module>)
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:476(inv)
#         1    0.000    0.000   13.530   13.530 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:1482(svd)
#         4    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/fromnumeric.py:70(_wrapreduction)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/numeric.py:2264(isclose)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:672(cholesky)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/numeric.py:2344(within_tol)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:135(_commonType)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:32(seterr)
#         5    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:107(_makearray)
#         6    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2355(all)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2912(prod)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:132(geterr)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:102(get_linalg_error_extobj)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:125(_realType)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(inv)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(dot)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(all)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/numeric.py:2186(allclose)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/fromnumeric.py:71(<dictcomp>)
#         6    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:112(isComplexType)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:193(_assert_stacked_2d)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(prod)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(svd)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(result_type)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/_asarray.py:23(asarray)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:429(__init__)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(allclose)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:199(_assert_stacked_square)
#         4    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:433(__enter__)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/_ufunc_config.py:438(__exit__)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(isclose)
#         4    0.000    0.000    0.000    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:472(_unary_dispatcher)
#         4    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/multiarray.py:644(result_type)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/numeric.py:2182(_allclose_dispatcher)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/_asarray.py:110(asanyarray)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2907(_prod_dispatcher)
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(cholesky)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/multiarray.py:716(dot)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/numeric.py:2260(_isclose_dispatcher)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2350(_all_dispatcher)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:1478(_svd_dispatcher)

# %%
# %prun -q -D sghmc3.prof sghmc_with_data_numba2(data, logp_data_grad, logp_prior_grad, mb_size, theta_init, M, C, V_hat, epsilon, T, m)
import pstats
p = pstats.Stats('sghmc3.prof')
p.sort_stats('tottime').print_stats()
pass
# Out:
# <ipython-input-118-b84874ee8ecd>:34: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 1d, A))
#   r0 = r0 + epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0) +logp_prior_grad(theta0)) - epsilon*C@M_inv@r0 + sd @ np.random.randn(d)
# <ipython-input-118-b84874ee8ecd>:34: NumbaPerformanceWarning: '@' is faster on contiguous arrays, called on (readonly array(float64, 2d, A), readonly array(float64, 2d, A))
#   r0 = r0 + epsilon*((n/mb_size)*logp_data_grad(data_hat, theta0) +logp_prior_grad(theta0)) - epsilon*C@M_inv@r0 + sd @ np.random.randn(d)
#
# *** Profile stats marshalled to file 'sghmc3.prof'.
# Mon Apr 26 14:15:20 2021    sghmc3.prof
#
#          943946 function calls (875652 primitive calls) in 12.105 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1   10.712   10.712   10.712   10.712 <ipython-input-118-b84874ee8ecd>:27(update)
#      4129    0.781    0.000    0.785    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/ffi.py:111(__call__)
# 40486/18232    0.029    0.000    0.104    0.000 {method 'format' of 'str' objects}
#    176097    0.024    0.000    0.031    0.000 {built-in method builtins.isinstance}
# 20643/3793    0.020    0.000    0.029    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:313(_rec_list_vars)
# 23820/10109    0.016    0.000    0.101    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/_utils.py:44(__str__)
#      6982    0.015    0.000    0.048    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:13(__init__)
# 18126/18058    0.013    0.000    0.029    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/_utils.py:54(get_reference)
#      7158    0.012    0.000    0.086    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:219(_to_string)
#      8639    0.008    0.000    0.017    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/_utils.py:24(deduplicate)
#      8472    0.008    0.000    0.037    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:212(__init__)
#      8816    0.006    0.000    0.029    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:232(_set_name)
# 6403/5979    0.005    0.000    0.008    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/abstract.py:120(__eq__)
#      3278    0.005    0.000    0.017    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/weakref.py:395(__getitem__)
#  1770/358    0.005    0.000    0.041    0.000 /usr/local/lib/python3.7/site-packages/numba/core/runtime/context.py:180(get_meminfos)
# 14288/14212    0.005    0.000    0.012    0.000 {method 'join' of 'str' objects}
#      8816    0.005    0.000    0.023    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/_utils.py:16(register)
# 7646/5395    0.005    0.000    0.010    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/abstract.py:117(__hash__)
#      6982    0.005    0.000    0.006    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:338(_insert)
#      7670    0.005    0.000    0.005    0.000 {built-in method _abc._abc_instancecheck}
#        99    0.004    0.000    0.026    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:23(compute_use_defs)
#      6461    0.004    0.000    0.008    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:239(_get_reference)
#      4626    0.004    0.000    0.007    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#        36    0.004    0.000    0.004    0.000 {built-in method posix.getcwd}
#      2103    0.004    0.000    0.025    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:944(extract_value)
#     16459    0.004    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/_utils.py:13(is_used)
#      2103    0.004    0.000    0.008    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:639(descr)
#      2898    0.004    0.000    0.008    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:120(__init__)
#      1927    0.003    0.000    0.004    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/contextlib.py:81(__init__)
#      2103    0.003    0.000    0.018    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:624(__init__)
#       547    0.003    0.000    0.009    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:493(__init__)
#     12929    0.003    0.000    0.003    0.000 {built-in method builtins.hasattr}
# 9202/7532    0.003    0.000    0.048    0.000 {built-in method builtins.next}
#     26472    0.003    0.000    0.003    0.000 {method 'append' of 'list' objects}
#      2014    0.003    0.000    0.003    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ctypes/__init__.py:497(cast)
#        73    0.003    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:36(<listcomp>)
#      1963    0.003    0.000    0.010    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:77(__call__)
#       111    0.003    0.000    0.038    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/functions.py:280(get_call_type)
#    198/22    0.003    0.000    1.385    0.063 /usr/local/lib/python3.7/site-packages/numba/core/compiler_machinery.py:257(_runPass)
#     10688    0.002    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/abstract.py:95(key)
# 8920/6463    0.002    0.000    0.004    0.000 {built-in method builtins.hash}
#      1088    0.002    0.000    0.013    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:748(store)
# 7152/7114    0.002    0.000    0.004    0.000 {built-in method builtins.getattr}
#       100    0.002    0.000    0.008    0.000 /usr/local/lib/python3.7/site-packages/numba/np/numpy_support.py:349(ufunc_find_matching_loop)
#       285    0.002    0.000    0.007    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:65(__init__)
#        36    0.002    0.000    0.009    0.000 /usr/local/lib/python3.7/site-packages/numba/core/postproc.py:175(_patch_var_dels)
# 1927/1385    0.002    0.000    0.008    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/contextlib.py:116(__exit__)
#      4950    0.002    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/numba/core/utils.py:305(stream_list)
#        99    0.002    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:118(compute_dead_maps)
# 2815/2779    0.002    0.000    0.008    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:130(_get_reference)
#     14075    0.002    0.000    0.002    0.000 {method 'add' of 'set' objects}
#      7670    0.002    0.000    0.006    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/abc.py:137(__instancecheck__)
# 1927/1352    0.002    0.000    0.038    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/contextlib.py:107(__enter__)
#       285    0.002    0.000    0.007    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:113(_descr)
# 2956/2344    0.002    0.000    0.003    0.000 {built-in method builtins.sorted}
#        98    0.002    0.000    0.002    0.000 {built-in method builtins.__build_class__}
#      1088    0.002    0.000    0.008    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:419(descr)
# 1370/1365    0.002    0.000    0.002    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       912    0.002    0.000    0.010    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:735(load)
#       110    0.002    0.000    0.007    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:177(set_weights)
#       473    0.002    0.000    0.097    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:799(<listcomp>)
#      4467    0.002    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:30(__ne__)
# 17093/17047    0.002    0.000    0.002    0.000 {built-in method builtins.len}
#      3115    0.002    0.000    0.018    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/manager.py:22(lookup)
#       367    0.002    0.000    0.006    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:548(_icmp)
#         1    0.002    0.002    0.002    0.002 {method 'multivariate_normal' of 'numpy.random.mtrand.RandomState' objects}
#      6777    0.002    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/_utils.py:71(_stringify_metadata)
#      7220    0.002    0.000    0.002    0.000 {method 'rstrip' of 'str' objects}
#       514    0.002    0.000    0.016    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:865(gep)
#      2427    0.002    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/npytypes.py:453(key)
#      4950    0.002    0.000    0.007    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/templates.py:1174(new_registrations)
#        18    0.002    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/executionengine.py:138(_find_module_ptr)
#      7248    0.002    0.000    0.002    0.000 {method 'insert' of 'list' objects}
#     17399    0.002    0.000    0.002    0.000 {method 'extend' of 'list' objects}
#       220    0.002    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:81(def_reach)
#      1242    0.002    0.000    0.016    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:626(get)
#       912    0.002    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:399(descr)
#       319    0.001    0.000    0.019    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:362(alloca_once)
#     10002    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:182(block)
#      1927    0.001    0.000    0.005    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/contextlib.py:237(helper)
#       245    0.001    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:235(compute_cfg_from_blocks)
#   271/205    0.001    0.000    0.324    0.002 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:321(lower_inst)
#      2856    0.001    0.000    0.004    0.000 {method 'get' of 'dict' objects}
#       358    0.001    0.000    0.047    0.000 /usr/local/lib/python3.7/site-packages/numba/core/runtime/context.py:197(_call_incref_decref)
#      4950    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/utils.py:314(sublist_iterator)
#      1088    0.001    0.000    0.009    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:415(__init__)
#      1301    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:538(__iter__)
#      2023    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:240(format_constant)
#       348    0.001    0.000    0.016    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:284(if_then)
#       504    0.001    0.000    0.006    0.000 /usr/local/lib/python3.7/site-packages/numba/core/base.py:361(install_registry)
#      1621    0.001    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/ffi.py:257(close)
#      7930    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:229(_get_name)
#       912    0.001    0.000    0.007    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:394(__init__)
#       804    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/value.py:143(name)
#       547    0.001    0.000    0.007    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:515(descr)
#       380    0.001    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:528(_rate_arguments)
#      1336    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/np/numpy_support.py:331(ufunc_can_cast)
#      1242    0.001    0.000    0.007    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/module.py:213(__next__)
#         1    0.001    0.001    0.001    0.001 {method 'choice' of 'numpy.random.mtrand.RandomState' objects}
#       612    0.001    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:729(__init__)
#      2975    0.001    0.000    0.025    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:346(list_vars)
#        99    0.001    0.000    0.056    0.001 /usr/local/lib/python3.7/site-packages/numba/core/postproc.py:68(run)
#       547    0.001    0.000    0.011    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:899(gep)
#      1032    0.001    0.000    0.016    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:706(getter)
#      4129    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/ffi.py:55(__getattr__)
#      3774    0.001    0.000    0.001    0.000 {method 'startswith' of 'str' objects}
#      1578    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:250(function_type)
#      2778    0.001    0.000    0.017    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/manager.py:33(__getitem__)
#       530    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:423(wrap_constant_value)
#       226    0.001    0.000    0.007    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/module.py:45(add_metadata)
#        18    0.001    0.000    0.023    0.001 /usr/local/lib/python3.7/site-packages/numba/core/rewrites/registry.py:54(apply)
#       368    0.001    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:309(__init__)
#       810    0.001    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:414(install_registry)
#      1545    0.001    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/ffi.py:300(__del__)
#       598    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/value.py:206(is_declaration)
#      1663    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/ffi.py:267(detach)
#        99    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:190(compute_live_variables)
#     19/13    0.001    0.000    0.327    0.025 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:220(lower_block)
#       368    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:325(descr)
#      2103    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:640(<listcomp>)
#       123    0.001    0.000    0.006    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/packer.py:73(__init__)
#      1363    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:1196(find_insts)
#       834    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:896(__getitem__)
#        36    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/compiler_machinery.py:341(dependency_analysis)
#       119    0.001    0.000    0.008    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:593(__init__)
#       578    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeconv/typeconv.py:43(check_compatible)
#       994    0.001    0.000    0.001    0.000 {method 'keys' of 'dict' objects}
#      2514    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:670(get_field_position)
#       143    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:91(liveness)
# 3022/1390    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/packer.py:144(rec)
#   164/101    0.001    0.000    0.017    0.000 /usr/local/lib/python3.7/site-packages/numba/core/base.py:539(get_function)
#       638    0.001    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:268(goto_entry_block)
#        57    0.001    0.000    0.006    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:578(resolve_overload)
#     96/72    0.001    0.000    0.506    0.007 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:568(resolve)
#      7155    0.001    0.000    0.001    0.000 {method 'values' of 'dict' objects}
#       808    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:381(_dfs)
#       667    0.001    0.000    0.013    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:158(__setattr__)
#       699    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/module.py:233(_next)
#       514    0.001    0.000    0.017    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:858(gep_inbounds)
#      1331    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:116(__init__)
#       560    0.001    0.000    0.022    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/templates.py:343(apply)
#      6405    0.001    0.000    0.001    0.000 {built-in method builtins.iter}
#      1664    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:558(__eq__)
#       169    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:712(<listcomp>)
#      1223    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/value.py:81(__init__)
#       351    0.001    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:651(__init__)
#      1069    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:121(_to_string)
#   740/457    0.001    0.000    0.043    0.000 /usr/local/lib/python3.7/site-packages/numba/core/utils.py:274(__get__)
#      1034    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/errors.py:724(new_error_context)
#       561    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:66(fix_point_progress)
#       444    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/functions.py:77(add_error)
#   328/103    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/packer.py:123(_assign_names)
#       351    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:669(descr)
#      1948    0.001    0.000    0.013    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:579(list_vars)
#       306    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/np/numpy_support.py:119(as_dtype)
#       385    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:30(descr)
#   491/357    0.001    0.000    0.001    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pprint.py:490(_safe_repr)
#       100    0.001    0.000    0.014    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/npydecl.py:96(generic)
#       420    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/errors.py:437(catch_warnings)
#      1807    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:231(__eq__)
#      1569    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/ffi.py:250(__init__)
#       473    0.001    0.000    0.098    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:797(descr)
# 1400/1319    0.001    0.000    0.004    0.000 {built-in method builtins.any}
#      2303    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:116(successors)
#       285    0.001    0.000    0.008    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:854(call)
#     18/10    0.001    0.000    0.515    0.052 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:141(propagate)
#       544    0.001    0.000    0.001    0.000 {built-in method numpy.core._multiarray_umath.dragon4_positional}
#       385    0.001    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:18(wrapped)
#       126    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:653(_find_loops)
#      2123    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:69(<genexpr>)
#       543    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/module.py:244(_next)
#       612    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:683(__init__)
#       254    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:394(_eliminate_dead_blocks)
# 1142/1056    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:127(__eq__)
#   384/123    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/packer.py:175(rec)
#        79    0.001    0.000    0.022    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/module.py:11(parse_assembly)
#       163    0.001    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/typeof.py:25(typeof)
#      1181    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:27(as_pointer)
#       473    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:779(__init__)
#   290/256    0.001    0.000    0.007    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/abstract.py:60(__call__)
#      2021    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/compiler.py:269(__getattr__)
#       189    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/_utils.py:9(__init__)
#       473    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:619(append_basic_block)
#       148    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:560(__repr__)
#       351    0.001    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:954(insert_value)
#       718    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:173(__eq__)
#      1464    0.001    0.000    0.001    0.000 {built-in method __new__ of type object at 0x107e0cac0}
#      1023    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/containers.py:243(key)
#       9/1    0.001    0.000    1.386    1.386 /usr/local/lib/python3.7/site-packages/numba/core/compiler_machinery.py:316(run)
#       272    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/arrayprint.py:974(__call__)
#       389    0.001    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:167(descr)
#        53    0.001    0.000    0.002    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/inspect.py:2117(_signature_from_function)
#      1336    0.001    0.000    0.002    0.000 <__array_function__ internals>:2(can_cast)
#       356    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/ffi.py:188(close)
#       612    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:716(_to_list)
# 1297/1216    0.001    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/misc.py:47(unliteral)
#        32    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/pythonapi.py:168(__init__)
#        96    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:496(fold_arg_vars)
#    334/10    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/arrayprint.py:745(recurser)
#       882    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:444(elements)
#       164    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/interpreter.py:394(store)
#       547    0.001    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:516(<listcomp>)
#        75    0.001    0.000    0.022    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:99(__init__)
#       473    0.001    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:163(__init__)
#    594/66    0.001    0.000    1.384    0.021 /usr/local/lib/python3.7/site-packages/numba/core/compiler_machinery.py:261(check)
#      1052    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:681(get_type)
#      2514    0.001    0.000    0.001    0.000 {method 'index' of 'tuple' objects}
#       137    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:570(_find_back_edges)
#       473    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:344(_set_terminator)
#       796    0.001    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:182(__hash__)
#       324    0.001    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:717(alloca)
#       161    0.001    0.000    0.006    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:360(resolve_value_type)
#       709    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:503(can_convert)
#      1301    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:527(__init__)
#      1461    0.001    0.000    0.001    0.000 {method 'decode' of 'bytes' objects}
#      1122    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:228(position_at_end)
#       694    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:416(parent)
#        15    0.001    0.000    0.001    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ctypes/__init__.py:47(create_string_buffer)
#       324    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:475(__init__)
#       9/3    0.001    0.000    1.253    0.418 /usr/local/lib/python3.7/site-packages/numba/core/typed_passes.py:349(run_pass)
#       527    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ssa.py:177(_run_ssa_block_pass)
#        72    0.001    0.000    0.013    0.000 /usr/local/lib/python3.7/site-packages/numba/core/base.py:266(refresh)
#       389    0.001    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:169(<listcomp>)
#       718    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:251(goto_block)
#       493    0.001    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:748(__str__)
#       100    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/npydecl.py:24(_handle_inputs)
#       808    0.001    0.000    0.001    0.000 {built-in method _functools.reduce}
#        46    0.001    0.000    0.009    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:33(_get_ll_pointer_type)
#        81    0.001    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:686(load_additional_registries)
#       155    0.001    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:479(descr)
#     205/1    0.001    0.000    1.388    1.388 /usr/local/lib/python3.7/site-packages/numba/core/compiler_lock.py:29(_acquire_compile_lock)
#        83    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/common.py:48(__init__)
#       155    0.001    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:467(__init__)
#      1026    0.001    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:379(__getattr__)
#       217    0.001    0.000    0.012    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:173(__setitem__)
#       473    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#      1889    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#       625    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#       119    0.000    0.000    0.007    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:631(descr_prototype)
#       307    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:593(push_state)
#       360    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:366(_add_edge)
#         9    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir_utils.py:1926(raise_on_unsupported_feature)
#       129    0.000    0.000    0.035    0.000 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:1258(storevar)
#      2727    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#     62/45    0.000    0.000    0.248    0.006 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:997(lower_expr)
#       167    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:1185(find_exprs)
#       338    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:198(module)
#       464    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/base.py:492(get_value_type)
#      1015    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:205(__new__)
#       285    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:114(<listcomp>)
#     96/72    0.000    0.000    0.503    0.007 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:1500(resolve_call)
#       675    0.000    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/functions.py:229(_unlit_non_poison)
#        72    0.000    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cpu.py:65(load_additional_registries)
#       122    0.000    0.000    0.018    0.000 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:1282(delvar)
#         9    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#       210    0.000    0.000    0.000    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/warnings.py:470(__enter__)
#        15    0.000    0.000    0.050    0.003 /usr/local/lib/python3.7/site-packages/numba/core/codegen.py:563(_optimize_functions)
#    122/72    0.000    0.000    0.502    0.007 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:231(_resolve_user_function_type)
#       265    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:493(traverse)
#         9    0.000    0.000    0.005    0.001 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:78(run)
#       125    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/cffi/api.py:194(typeof)
#       167    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:1077(add_type)
#        18    0.000    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/numba/core/codegen.py:1049(<setcomp>)
#       612    0.000    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:637(<genexpr>)
#       290    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/abstract.py:48(_intern)
#       247    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/templates.py:179(signature)
#      1508    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/templates.py:355(<genexpr>)
#        83    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/npytypes.py:418(__init__)
#        19    0.000    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/numba/core/inline_closurecall.py:1317(_inline_const_arraycall)
#       254    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:87(__init__)
#       125    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/typeof.py:60(_typeof_buffer)
#      2925    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#       122    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:103(traverse_types)
#       137    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:205(_back_edges)
#       226    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/module.py:21(_fix_metadata_operands)
#       882    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:352(__init__)
#        20    0.000    0.000    0.041    0.002 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:562(lower_binop)
#       170    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/templates.py:669(_get_impl)
#       265    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:496(<listcomp>)
#        19    0.000    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:1229(dump)
#        70    0.000    0.000    0.113    0.002 /usr/local/lib/python3.7/site-packages/llvmlite/ir/module.py:212(<listcomp>)
#       913    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:191(function)
#      1359    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:124(predecessors)
#       125    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/typeof.py:39(typeof_impl)
#       118    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/cffi/api.py:952(_builtin_function_type)
#       200    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/np/numpy_support.py:379(choose_types)
#       594    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/compiler_machinery.py:24(__exit__)
#       662    0.000    0.000    0.001    0.000 {built-in method builtins.all}
#       259    0.000    0.000    0.007    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:847(__str__)
#       543    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:262(typeof)
#       198    0.000    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:71(fix_point)
#       362    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#       572    0.000    0.000    0.000    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/enum.py:356(__getitem__)
#         6    0.000    0.000    0.033    0.006 /usr/local/lib/python3.7/site-packages/numba/np/npyimpl.py:230(_build_array)
#        34    0.000    0.000    0.023    0.001 /usr/local/lib/python3.7/site-packages/numba/core/callconv.py:547(call_function)
#       396    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/compiler_machinery.py:128(__init__)
#       246    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:248(_get_attribute_templates)
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#      1142    0.000    0.000    0.001    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/logging/__init__.py:1356(debug)
#       171    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir_utils.py:2106(enforce_no_dels)
#    129/96    0.000    0.000    0.263    0.003 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:492(lower_assign)
#       440    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:533(add)
#        80    0.000    0.000    0.036    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:684(__call__)
#    214/20    0.000    0.000    0.004    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pprint.py:154(_format)
#       152    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:260(dispatch)
#       301    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:200(fix_point_progress)
#        42    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:990(_mangle_arg_name)
#       173    0.000    0.000    0.008    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:166(__getitem__)
#        15    0.000    0.000    0.187    0.012 /usr/local/lib/python3.7/site-packages/numba/core/codegen.py:641(add_ir_module)
#       250    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:441(_lookup_global)
#        10    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/arrayprint.py:890(fillFormat)
#       274    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:456(__init__)
#       274    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/module.py:138(add_global)
#        80    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:609(select)
#       473    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:813(_format_name)
#       100    0.000    0.000    0.014    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/npydecl.py:171(generic)
#        10    0.000    0.000    0.019    0.002 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:3348(_empty_nd_impl)
#       178    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/ffi.py:183(__init__)
#        21    0.000    0.000    0.009    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:179(populate_array)
#       183    0.000    0.000    0.001    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/inspect.py:2467(__init__)
#       792    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/compiler_machinery.py:400(is_registered)
#       210    0.000    0.000    0.001    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/warnings.py:181(_add_filter)
#       884    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:359(__getitem__)
#       433    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:235(append_basic_block)
#        53    0.000    0.000    0.002    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/inspect.py:2198(_signature_from_callable)
#      2046    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:246(wrap_constant_value)
#        99    0.000    0.000    0.006    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:60(compute_live_map)
#      1640    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/templates.py:46(args)
#         9    0.000    0.000    0.017    0.002 /usr/local/lib/python3.7/site-packages/numba/core/interpreter.py:102(interpret)
#       430    0.000    0.000    0.015    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:142(_get_ptr_by_index)
#       710    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#       117    0.000    0.000    0.006    0.000 /usr/local/lib/python3.7/site-packages/numba/core/errors.py:478(__init__)
#       194    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:266(core)
#        99    0.000    0.000    0.006    0.000 /usr/local/lib/python3.7/site-packages/numba/core/postproc.py:45(livemap)
#       288    0.000    0.000    0.001    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/os.py:676(__getitem__)
#       201    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:813(cbranch)
#        18    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir_utils.py:1466(build_definitions)
#         9    0.000    0.000    0.008    0.001 /usr/local/lib/python3.7/site-packages/numba/core/inline_closurecall.py:69(run)
#       501    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:687(__init__)
#      1994    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/analysis.py:40(<genexpr>)
#       210    0.000    0.000    0.000    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/warnings.py:489(__exit__)
#       373    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/numba/core/base.py:46(find)
#        99    0.000    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/numba/core/transforms.py:239(canonicalize_cfg_single_backedge)
#       348    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:236(fixup)
#         9    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/codegen.py:693(_finalize_dyanmic_globals)
#       333    0.000    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/functions.py:295(<listcomp>)
#      1723    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/common.py:27(_is_shutting_down)
#       188    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:805(branch)
#        70    0.000    0.000    0.114    0.002 /usr/local/lib/python3.7/site-packages/llvmlite/ir/module.py:207(_get_body_lines)
#       114    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/module.py:52(__init__)
#       127    0.000    0.000    0.013    0.000 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:1301(alloca_lltype)
#      1196    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:529(get_value_type)
#       385    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:34(<listcomp>)
#        80    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:295(descr)
#       261    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:1251(loadvar)
#         6    0.000    0.000    0.166    0.028 /usr/local/lib/python3.7/site-packages/numba/np/ufunc/array_exprs.py:329(_lower_array_expr)
#      1542    0.000    0.000    0.001    0.000 {built-in method builtins.issubclass}
#       880    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:48(get_argument_type)
#        69    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:1607(typeof_expr)
#       594    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/compiler_machinery.py:20(__enter__)
#        27    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/containers.py:256(__unliteral__)
#       148    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/interpreter.py:369(_dispatch)
#     80/16    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/serialize.py:299(save)
#        34    0.000    0.000    0.005    0.000 /usr/local/lib/python3.7/site-packages/numba/core/callconv.py:454(_get_return_status)
#        79    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/binding/context.py:8(get_global_context)
#        54    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/callconv.py:409(check_try_status)
#       324    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/instructions.py:481(descr)
#        99    0.000    0.000    0.011    0.000 /usr/local/lib/python3.7/site-packages/numba/core/postproc.py:51(deadmaps)
#       119    0.000    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:600(<listcomp>)
#        74    0.000    0.000    0.003    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:621(pack_array)
#       153    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:1165(check_var)
#       112    0.000    0.000    0.001    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/misc.py:56(literal)
#        27    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir_utils.py:488(remove_dels)
#       132    0.000    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:1434(typeof_assign)
#       163    0.000    0.000    0.004    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/functools.py:835(wrapper)
#       173    0.000    0.000    0.008    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:149(__getattr__)
#        70    0.000    0.000    0.115    0.002 /usr/local/lib/python3.7/site-packages/llvmlite/ir/module.py:233(__repr__)
#        37    0.000    0.000    0.006    0.000 /usr/local/lib/python3.7/site-packages/numba/core/callconv.py:490(decorate_function)
#        30    0.000    0.000    0.004    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:547(_as)
#       9/3    0.000    0.000    1.254    0.418 /usr/local/lib/python3.7/site-packages/numba/core/typed_passes.py:437(run_pass)
#       398    0.000    0.000    0.002    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:127(_to_string)
# ...
#         9    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:499(inner_models)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:591(__init__)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:820(__init__)
#         6    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:959(infer_constant)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/llvmpy/core.py:118(real)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/funcdesc.py:123(llvm_cfunc_wrapper_name)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/dispatcher.py:118(_get_implementation)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/interpreter.py:962(op_GET_ITER)
#         9    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/interpreter.py:1111(op_BINARY_ADD)
#         5    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/interpreter.py:1114(op_BINARY_SUBTRACT)
#         7    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/interpreter.py:1135(op_BINARY_MATRIX_MULTIPLY)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/interpreter.py:1371(op_CALL_METHOD)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:739(op_STORE_SUBSCR)
#         5    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:752(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:837(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:1030(op_CALL_METHOD)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:1084(__eq__)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/bytecode.py:80(is_jump)
#         6    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:459(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:1272(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:1275(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:1278(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:426(__init__)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:471(get_call_signature)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:733(_refine_target_type)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:755(__init__)
#        18    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:1711(propagate_finished)
#         3    0.000    0.000    0.002    0.001 /usr/local/lib/python3.7/site-packages/numba/core/callwrapper.py:66(emit_cleanup)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/inline_closurecall.py:116(<lambda>)
#         9    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/inline_closurecall.py:755(_debug_dump)
#        20    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ssa.py:211(on_other)
#        24    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ssa.py:267(on_other)
#         8    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/arraydecl.py:518(generic)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/cpython/tupleobj.py:391(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/cpython/numbers.py:19(_int_arith_flags)
#         6    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/npyimpl.py:311(_unpack_output_types)
#         6    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/npyimpl.py:325(_pack_output_values)
#         3    0.000    0.000    0.000    0.000 {method 'from_address' of '_ctypes.PyCArrayType' objects}
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/multiarray.py:143(concatenate)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/multiarray.py:716(dot)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(result_type)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/numeric.py:2182(_allclose_dispatcher)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(allclose)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(isclose)
#         6    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:112(isComplexType)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:1478(_svd_dispatcher)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/types.py:448(__len__)
#         6    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/values.py:615(basic_blocks)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/containers.py:362(<genexpr>)
#         9    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/errors.py:181(indicate)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/functions.py:535(get_impl_key)
#         9    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:146(init)
#         9    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/context.py:628(keyfunc)
#         3    0.000    0.000    0.000    0.000 {built-in method numba.core.typeconv._typeconv.get_pointer}
#         5    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typing/typeof.py:154(_typeof_none)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:182(get_value_type)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:473(iternext)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/imputils.py:256(__init__)
#         9    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:63(init)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:696(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:1162(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/lowering.py:1163(<listcomp>)
#         9    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/debuginfo.py:61(finalize)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/controlflow.py:695(<lambda>)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/dispatcher.py:121(_customize_flags)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/dispatcher.py:183(__bool__)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/dispatcher.py:329(is_compiling)
#         9    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/interpreter.py:349(code_consts)
#         5    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/interpreter.py:842(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/interpreter.py:1368(op_LOAD_METHOD)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:1027(op_LOAD_METHOD)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:1192(push_block)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:1198(reset_stack)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/callconv.py:594(fp_zero_division)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/base.py:338(nonconst_module_attrs)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:612(__init__)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:968(get_shape)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:225(__init__)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:408(__init__)
#         9    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:1714(unify_finished)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/codegen.py:544(codegen)
#         9    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/compiler_machinery.py:245(finalized)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/npyimpl.py:45(update_indices)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/npyimpl.py:79(create_iter_indices)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/npyimpl.py:82(load_data)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.globals}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         3    0.000    0.000    0.000    0.000 /usr/local/Cellar/python@3.7/3.7.10_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py:507(is_set)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/multiarray.py:644(result_type)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/numeric.py:2260(_isclose_dispatcher)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2350(_all_dispatcher)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2907(_prod_dispatcher)
#         4    0.000    0.000    0.000    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py:472(_unary_dispatcher)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/llvmlite/ir/builder.py:537(neg)
#        18    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/abstract.py:147(can_convert_from)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/types/containers.py:220(__len__)
#         9    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/errors.py:172(code)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:37(<listcomp>)
#         5    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cgutils.py:202(_getpointer)
#         6    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:239(as_return)
#         8    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/datamodel/models.py:714(inner_models)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:989(infer_constant)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir_utils.py:400(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/ir.py:1256(insert_after)
#         9    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/debuginfo.py:55(mark_subprogram)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/dispatcher.py:211(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/interpreter.py:1123(op_BINARY_TRUE_DIVIDE)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/byteflow.py:1179(peek)
#         4    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/base.py:78(<lambda>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/base.py:495(pack_value)
#        10    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/base.py:1110(get_preferred_array_alignment)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:630(get_shape)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:668(prepare)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:674(get_shape)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:681(loop_head)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:684(loop_tail)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:1274(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:1276(<listcomp>)
#         2    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/np/arrayobj.py:1406(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:779(get_call_signature)
#        18    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/typeinfer.py:1708(propagate_started)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/cpu.py:243(<lambda>)
#        18    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/inline_closurecall.py:299(check)
#         3    0.000    0.000    0.000    0.000 /usr/local/lib/python3.7/site-packages/numba/core/caching.py:98(save_overload)
#         1    0.000    0.000    0.000    0.000 <ipython-input-118-b84874ee8ecd>:1(<module>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-114-b807f05dee81>:1(<module>)

# %%
p = 5
true_theta = np.arange(p)
size = 10000
X = np.random.randn(size,p)
y = np.dot(X,true_theta) + np.random.randn(size)
data = np.c_[y,X]

theta_init = np.zeros(p)
M = np.eye(p)
C = 13*np.eye(p)
V_hat = 0
T = 1000
m = 50
epsilon = 0.0001
mb_size=1000

# %%
# %prun -q -D sghmc3.prof sghmc_with_data(data, logp_data_grad, logp_prior_grad, mb_size, theta_init, M, C, V_hat, epsilon, T, m)
import pstats
p = pstats.Stats('sghmc3.prof')
p.sort_stats('tottime').print_stats()
pass
# Out:
#
# *** Profile stats marshalled to file 'sghmc3.prof'.
